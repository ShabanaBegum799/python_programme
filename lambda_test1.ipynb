# %%
bbalance=700000
event={"name":"shabana","a/c no":9848344799,"amount":8000,"credit type":"credit","loan":"yes","location":"non_metro","age":25,"employment_type":"salaried"}
def details(event):
    if event["name"]=="shabana":
         if event["credit type"]=="debit":
            balance=bbalance-event["amount"]
            if event["loan"]=="yes":
                balance=balance-1000
                if event["location"]=="non_metro":
                    balance=balance-2000                        
                    if event["age"]>25:
                        balance=balance+18000
                        elif["age"]<=25:
                            balance=balance+0
                            if event["employment_type"]=="salaried":
                                balance=balance+0
                            elif event["employment_type"]=="individual":
                                balance=balance+1000
                            elif event["employmet_type"]=="bussiness":
                                balance=balance+500
            elif event["loan"]=="no":
                balance=balance+1000
                if event["location"]=="metro":
                    balance=balance+2000                        
                    if event["age"]>25:
                        balance=balance+18000
                        elif event["age"]<=25:
                            balance=balance+0
                            if event["employment_type"]=="salaried":
                                balance=balance+0
                            elif event["employment_type"]=="individual":
                                balance=balance+1000
                            elif event["employmet_type"]=="bussiness":
                                balance=balance+500
            elif event["loan"]=="yes":
                balance=balance-1000
                if event["location"]=="non_metro":
                    balance=balance-2000                        
                    if event["age"]>25:
                        balance=balance+18000
                        elif["age"]<=25:
                            balance=balance+0
                            if event["employment_type"]=="salaried":
                                balance=balance+0
                            elif event["employment_type"]=="individual":
                                balance=balance+1000
                            elif event["employmet_type"]=="bussiness":
                                balance=balance+500
                                
            elif event["loan"]=="yes":
                balance=balance-1000
                if event["location"]=="metro":
                    balance=balance+2000                        
                    if event["age"]>25:
                        balance=balance+18000
                        elif event["age"]<=25:
                            balance=balance+0
                            if event["employment_type"]=="salaried":
                                balance=balance+0
                            elif event["employment_type"]=="individual":
                                balance=balance+1000
                            elif event["employmet_type"]=="bussiness":
                                balance=balance+500
                                
            elif event["loan"]=="no":
                balance=balance+1000
                if event["location"]=="non_metro":
                    balance=balance-2000                        
                    if event["age"]>25:
                        balance=balance+18000
                        elif event["age"]<=25:
                            balance=balance+0
                            if event["employment_type"]=="salaried":
                                balance=balance+0
                            elif event["employment_type"]=="individual":
                                balance=balance+1000
                            elif event["employmet_type"]=="bussiness":
                                balance=balance+500
                             
                                
                                
                                
                                
                                
                            
               
        
     
    return balance    
            
details(event)
# Out:
#   Cell In[1], line 13
#     elif["age"]<=25:
#     ^
# SyntaxError: invalid syntax

# %%
bbalance=700000
event={"name":"shabana","a/c no":9848344799,"amount":8000,"credit type":"debit","loan":"yes","location":"non_metro","age":23,"employment_type":"salaried"}
def details(event):
    if event["name"]=="shabana":
         if event["credit type"]=="debit":
            balance=bbalance-event["amount"]
            if event["loan"]=="yes":
                balance=balance-1000
                if event["location"]=="non_metro":
                    balance=balance-2000                        
                    if event["age"]>25:
                        balance=balance+18000
                        if event["employment_type"]=="salaried":
                            balance=balance+0
                        elif event["employment_type"]=="individual":
                            balance=balance+1000
                        elif event["employmet_type"]=="bussiness":
                            balance=balance+500
                    elif event["age"]<=25:
                        balance=balance+0
                        if event["employment_type"]=="salaried":
                            balannce=balance
                        elif evnent["employment_type"]=="individual":
                            balance=balance+1000
                        elif evnet["employment_type"] =="bussiness":
                            balance=balance+500
    return balance
details(event)
# Out:
# 689000

# %%
elif event["age"]<=25:
                        balance=balance+18000
                        if event["employment_type"]=="salaried":
                            balannce=balance
                        elif evnent["employment_type"]="individual":
                            balance=balance+10000
                        elif evnet["employment_type"] ="bussiness":
                            balance=balance+500
            elif event["location"]=="non_metro"
                balance=balance-2000
                if event["age"]>25:
                    balance=balance+18000
                    if event["emoployment_type"]=="salaried":
                        balance=balance+0
                    elif event["employmebt_type"]=="individual":
                        balance=balance+1000
                    elif event["employment_type"]=="bussiness":
                        balance=balance+500
        elif event["credit_type"]=="credit":
            balance=bbalance+event["amount"]
            if event["loan"]=="no":
                balance=balance+1000
                if event["location"]=="metro":
                    balance=balance-2000
                    if event["age"]<=25:
                        balance=balance
                        if event["employment_type"]=="salaried":
                            balance=balance+0
                        elif event["employment_type"]=="individual":
                            balance=balance-1000
                        elif event["employment_type"]=="bussiness":
                            balance=balance-500
