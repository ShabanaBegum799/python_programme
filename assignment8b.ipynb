# %%
import pandas
import pandas as pd
familymembers=pd.read_excel(r"C:\Users\HP\Documents\Shabana-pandas\family members.xlsx")
familymembers
# Out:
#   family_members relation
# 0         mazeed   father
# 1    zahurunnisa   mother
# 2        zareena   sister
# 3          siraj  brother

# %%
import pandas
import pandas as pd
friendsnames=pd.read_excel(r"C:\Users\HP\Documents\Shabana-pandas\friendsnames.xlsx")
friendsnames
# Out:
#   friendsname  age  gender qualification
# 0    nasheena   25  female        degree
# 1     parveen   28  female        degree
# 2      anusha   28  female        degree
# 3    jayasree   25  female         btech
# 4      reshma   23  female        degree

# %%
import pandas
import pandas as pd
vegfood_items=pd.read_excel(r"C:\Users\HP\Documents\Shabana-pandas\vegfood_items.xlsx")
vegfood_items
# Out:
#       vegfood_items   taste
# 0       potatochips  sality
# 1   panneer biryani   spicy
# 2  mashroom biryani  sality
# 3          babycorn  crispy

# %%
import pandas
import pandas as pd
nonveg=pd.read_excel(r"C:\Users\HP\Documents\Shabana-pandas\nonveg.xlsx")
nonveg
# Out:
#       nonveg_items  taste
# 0  chicken biryani  spicy
# 1   mutton biryani  spicy
# 2     fish biryani  spicy

# %%
import pandas
import pandas as pd
colour_names=pd.read_excel(r"C:\Users\HP\Documents\Shabana-pandas\colour_names.xlsx")
colour_names
# Out:
#   colourname_english  hindi      telugu
# 0                red   laal       erupu
# 1              white  safed      telupu
# 2             yellow  peela      pasupu
# 3              green   hara  aakupatcha

# %%
import pandas
import pandas as pd
vegfood_items=pd.read_excel(r"C:\Users\HP\Documents\Shabana-pandas\vegfood_items.xlsx")
vegfood_items
# Out:
#       vegfood_items   taste
# 0       potatochips  sality
# 1   panneer biryani   spicy
# 2  mashroom biryani  sality
# 3          babycorn  crispy

# %%
import pandas
import pandas as pd
nonveg_items=pd.read_excel(r"C:\Users\HP\Documents\Shabana-pandas\nonveg.xlsx")
nonveg_items
# Out:
#       nonveg_items  taste
# 0  chicken biryani  spicy
# 1   mutton biryani  spicy
# 2     fish biryani  spicy

# %%
import pandas
import pandas as pd
monthnames_season=pd.read_excel(r"C:\Users\HP\Documents\Shabana-pandas\monthnames-season.xlsx")
monthnames_season
# Out:
#   monthnames  season
# 0    january  winter
# 1   february  winter
# 2      march   rainy
# 3      april   rainy
# 4        may  summer
# 5       june  summer

# %%
import pandas
import pandas as pd
colour_names=pd.read_excel(r"C:\Users\HP\Documents\Shabana-pandas\colour_names.xlsx")
colour_names
# Out:
#   colourname_english  hindi      telugu
# 0                red   laal       erupu
# 1              white  safed      telupu
# 2             yellow  peela      pasupu
# 3              green   hara  aakupatcha

# %%
import pandas
import pandas as pd
friendsnames=pd.read_excel(r"C:\Users\HP\Documents\Shabana-pandas\friendsnames.xlsx",sheet_name="Sheet2")
friendsnames
# Out:
#   friendsname  age gender qualification
# 0    snathosh   26   male        betech
# 1       khaja   23   male        degree
# 2       imran   23   male        degree
