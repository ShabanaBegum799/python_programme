# %%
import pandas
import pandas as pd
df=pd.read_excel(r"C:\Users\HP\Documents\assignment10\friendsname_quality.xlsx")
df
# Out:
#   friendsnames      quality
# 0     nasheena  intilligent
# 1      parveen        funny
# 2       anusha  intilligent
# 3      jayasri  intilligent
# 4       reshma        angry
# 5        durga        funny
# 6      santhsh        funny
# 7        imran        angry
# 8        khaja        funny

# %%
lst=["intilligent"]
df_lst=df[df["quality"].isin(lst)]
df_lst
# Out:
#   friendsnames      quality
# 0     nasheena  intilligent
# 2       anusha  intilligent
# 3      jayasri  intilligent

# %%
lst=["funny"]
df_lst=df[df["quality"].isin(lst)]
df_lst
# Out:
#   friendsnames quality
# 1      parveen   funny
# 5        durga   funny
# 6      santhsh   funny
# 8        khaja   funny

# %%
lst=["intilligent","funny","angry"]
df_lst=df[~df["quality"].isin(lst)]
df_lst
# Out:
# Empty DataFrame
# Columns: [friendsnames, quality]
# Index: []

# %%
import pandas
import pandas as pd
df=pd.read_excel(r"C:\Users\HP\Documents\shabana_as9\familymembers-relation.xlsx")
df
# Out:
#   familymembersnames     relation
# 0             mazeed       father
# 1             safiya     daughter
# 2             saleem      brother
# 3              siraj      brother
# 4            zareena       sister
# 5        ameerunnisa  grandmother
# 6       khadarsharif  grandfather
# 7           shakeera        aunty
# 8          navabjani        uncle

# %%
lst=("brother","sister")
df_lst=df[df["relation"].isin(lst)]
df_lst
# Out:
#   familymembersnames relation
# 2             saleem  brother
# 3              siraj  brother
# 4            zareena   sister

# %%
lst2=["brother","sister"]
df[df.relation.isin(lst2)]
# Out:
#   familymembersnames relation
# 2             saleem  brother
# 3              siraj  brother
# 4            zareena   sister

# %%
lst=("father","grandfather","grandmother")
df_lst=df[df["relation"].isin(lst)]
df_lst
# Out:
#   familymembersnames     relation
# 0             mazeed       father
# 5        ameerunnisa  grandmother
# 6       khadarsharif  grandfather

# %%
lst=("father","grandfather","grandmother")
df_lst=df[~df["relation"].isin(lst)]
df_lst
# Out:
#   familymembersnames  relation
# 1             safiya  daughter
# 2             saleem   brother
# 3              siraj   brother
# 4            zareena    sister
# 7           shakeera     aunty
# 8          navabjani     uncle

# %%
df[df["relation"]=="brother"]
# Out:
#   familymembersnames relation
# 2             saleem  brother
# 3              siraj  brother

# %%
df[df["relation"]==(lst)]
# Out:
#   familymembersnames relation
# 2             saleem  brother
# 3              siraj  brother

# %%
df[df["relation"]=="sister"]
# Out:
#   familymembersnames relation
# 4            zareena   sister

# %%
lst=df[df["relation"]==(lst)]
# Out:
#   familymembersnames relation
# 2             saleem  brother
# 3              siraj  brother

# %%
df[df["relation"]!="father"]
# Out:
#   familymembersnames     relation
# 1             safiya     daughter
# 2             saleem      brother
# 3              siraj      brother
# 4            zareena       sister
# 5        ameerunnisa  grandmother
# 6       khadarsharif  grandfather
# 7           shakeera        aunty
# 8          navabjani        uncle

# %%
lst=["saleem","siraj"]
df[~df["familymembersnames"].isin(lst)]
# Out:
#   familymembersnames     relation
# 0             mazeed       father
# 1             safiya     daughter
# 4            zareena       sister
# 5        ameerunnisa  grandmother
# 6       khadarsharif  grandfather
# 7           shakeera        aunty
# 8          navabjani        uncle

# %%
df_or=df[(df["relation"]=="father")|(df["relation"]=="mother")]
df_or
# Out:
#   familymembersnames relation
# 0             mazeed   father

# %%
df_and=df[(df["familymembersnames"]=="safiya")&(df["relation"]=="daughter")]
df_and
# Out:
#   familymembersnames  relation
# 1             safiya  daughter

# %%
lst=("brother","father")
df_lst=df[df["relation"].isin(lst)]
df_lst
# Out:
#   familymembersnames relation
# 0             mazeed   father
# 2             saleem  brother
# 3              siraj  brother

# %%
lst=("father","brother")
df_lst=df[~df["relation"].isin(lst)]
df_lst
# Out:
#   familymembersnames     relation
# 1             safiya     daughter
# 4            zareena       sister
# 5        ameerunnisa  grandmother
# 6       khadarsharif  grandfather
# 7           shakeera        aunty
# 8          navabjani        uncle

# %%
lst=("father",)
df_lst=df[~df["relation"].isin(lst)]
df_lst
# Out:
#   familymembersnames     relation
# 1             safiya     daughter
# 2             saleem      brother
# 3              siraj      brother
# 4            zareena       sister
# 5        ameerunnisa  grandmother
# 6       khadarsharif  grandfather
# 7           shakeera        aunty
# 8          navabjani        uncle

# %%
lst=["father"]
df_lst=df[~df["relation"].isin(lst)]
df_lst
# Out:
#   familymembersnames     relation
# 1             safiya     daughter
# 2             saleem      brother
# 3              siraj      brother
# 4            zareena       sister
# 5        ameerunnisa  grandmother
# 6       khadarsharif  grandfather
# 7           shakeera        aunty
# 8          navabjani        uncle

# %%
lst=["father","brother"]
df_lst=df[~df["relation"].isin(lst)]
df_lst
# Out:
#   familymembersnames     relation
# 1             safiya     daughter
# 4            zareena       sister
# 5        ameerunnisa  grandmother
# 6       khadarsharif  grandfather
# 7           shakeera        aunty
# 8          navabjani        uncle

# %%
import pandas
import pandas as pd
df=pd.read_excel(r"C:\Users\HP\Documents\shabana_as9\vegfood_items.xlsx")
df
# Out:
#       vegfood_items   taste
# 0       potatochips  sality
# 1   panneer biryani   spicy
# 2  mashroom biryani  sality
# 3          babycorn  crispy
# 4       ladysfinger   curry
# 5            potato     fry
# 6           brinjal     fry
# 7           brinjal    soup

# %%
lst=["soup"]
df_lst=df[df["taste"].isin(lst)]
df_lst
# Out:
#   vegfood_items taste
# 7       brinjal  soup

# %%
lst=["curry"]
df_lst=df[df["taste"].isin(lst)]
df_lst
# Out:
#   vegfood_items  taste
# 4   ladysfinger  curry

# %%
lst=["fry"]
df_lst=df[df["taste"].isin(lst)]
df_lst
# Out:
#   vegfood_items taste
# 5        potato   fry
# 6       brinjal   fry

# %%
lst=["soup","fry"]
df_lst=df[df["taste"].isin(lst)]
df_lst
# Out:
#   vegfood_items taste
# 5        potato   fry
# 6       brinjal   fry
# 7       brinjal  soup

# %%
lst=["soup","fry"]
df_lst=df[~df["taste"].isin(lst)]
df_lst
# Out:
#       vegfood_items   taste
# 0       potatochips  sality
# 1   panneer biryani   spicy
# 2  mashroom biryani  sality
# 3          babycorn  crispy
# 4       ladysfinger   curry

# %%
lst=["soup","fry"]
df_lst=df[df["taste"].isin(lst)]
df_lst
# Out:
#   vegfood_items taste
# 5        potato   fry
# 6       brinjal   fry
# 7       brinjal  soup

# %%
import pandas
import pandas as pd
df=pd.read_excel(r"C:\Users\HP\Documents\shabana_as9\nonvegfood_items.xlsx")
df
# Out:
#       nonveg_items  taste
# 0  chicken biryani  spicy
# 1   mutton biryani  spicy
# 2     fish biryani  spicy
# 3           mutton    fry
# 4          chicken   soup
# 5          chicken    fry
# 6             fish  curry
# 7             fish   soup

# %%
df[df["nonveg_items"]=='chicken']
# Out:
#   nonveg_items taste
# 4      chicken  soup
# 5      chicken   fry

# %%
df[df["nonveg_items"]=="mutton"]
# Out:
#   nonveg_items taste
# 3       mutton   fry

# %%
lst=["fry"]
df_lst=df[df["taste"].isin(lst)]
df_lst
# Out:
#   nonveg_items taste
# 3       mutton   fry
# 5      chicken   fry

# %%
lst=["fry","chicken"]
df_lst=df[df["taste"].isin(lst)]
df_lst
# Out:
#   nonveg_items taste
# 3       mutton   fry
# 5      chicken   fry

# %%
lst=["fry","chicken"]
df_lst=df[~df["taste"].isin(lst)]
df_lst
# Out:
#       nonveg_items  taste
# 0  chicken biryani  spicy
# 1   mutton biryani  spicy
# 2     fish biryani  spicy
# 4          chicken   soup
# 6             fish  curry
# 7             fish   soup

# %%
lst=["fry","mutton"]
df_lst=df[df["taste"].isin(lst)]
df_lst
# Out:
#   nonveg_items taste
# 3       mutton   fry
# 5      chicken   fry

# %%
import pandas
import pandas
df=pd.read_excel(r"C:\Users\HP\Documents\Shabana-pandas\monthnames-season.xlsx")
df
# Out:
#    monthnames  season
# 0     january  winter
# 1    february  winter
# 2       march   rainy
# 3       april   rainy
# 4         may  summer
# 5        june  summer
# 6        july   rainy
# 7      august   rainy
# 8   september   rainy
# 9     october  winter
# 10   november  winter
# 11   december  winter

# %%
df[df["season"]=="winter"]
# Out:
#    monthnames  season
# 0     january  winter
# 1    february  winter
# 9     october  winter
# 10   november  winter
# 11   december  winter

# %%
lst=["winter"]
df_lst=df[df["season"].isin(lst)]
df_lst
# Out:
#    monthnames  season
# 0     january  winter
# 1    february  winter
# 9     october  winter
# 10   november  winter
# 11   december  winter

# %%
df[df["season"]=="summer"]
# Out:
#   monthnames  season
# 4        may  summer
# 5       june  summer

# %%
lst=["summer"]
df=df[df["season"].isin(lst)]
df
# Out:
#   monthnames  season
# 4        may  summer
# 5       june  summer

# %%
df[df["season"]=="rainy"]
# Out:
#   monthnames season
# 2      march  rainy
# 3      april  rainy
# 6       july  rainy
# 7     august  rainy
# 8  september  rainy

# %%
lst=["winter","summer"]
df=df[~df["season"].isin(lst)]
df
# Out:
# Empty DataFrame
# Columns: [monthnames, season]
# Index: []

# %%
df[df["season"]=="rainy"]
# Out:
#   monthnames season
# 2      march  rainy
# 3      april  rainy
# 6       july  rainy
# 7     august  rainy
# 8  september  rainy

# %%
df[df["season"]=="rainy"]
# Out:
#   monthnames season
# 2      march  rainy
# 3      april  rainy
# 6       july  rainy
# 7     august  rainy
# 8  september  rainy

# %%
lst=["winter","summer"]
df=df[df["season"].isin(lst)]
df
# Out:
#    monthnames  season
# 0     january  winter
# 1    february  winter
# 4         may  summer
# 5        june  summer
# 9     october  winter
# 10   november  winter
# 11   december  winter

# %%
lst=["winter","summer"]
df=df[~df["season"].isin(lst)]
df
# Out:
#   monthnames season
# 2      march  rainy
# 3      april  rainy
# 6       july  rainy
# 7     august  rainy
# 8  september  rainy

# %%
lst=["summer","rainy"]
df=df[~df["season"].isin(lst)]
df
# Out:
#    monthnames  season
# 0     january  winter
# 1    february  winter
# 9     october  winter
# 10   november  winter
# 11   december  winter

# %%
lst=["winter","rainy"]
df=df[df["season"].isin(lst)]
df
# Out:
#    monthnames  season
# 0     january  winter
# 1    february  winter
# 9     october  winter
# 10   november  winter
# 11   december  winter

# %%
import pandas
import pandas as pd
df=pd.read_excel(r"C:\Users\HP\Documents\Shabana-pandas\flowersnames.xlsx")
df
# Out:
#   flowersnames    hindi   telugu english
# 0         rose     laal    erupu     red
# 1        lilly    safed   telupu   white
# 2     hibiscus     laal    erupu     red
# 3    sunflower    peela   pasupu  yellow
# 4        lotus  gulaabi  gulaabi    pink
# 5       jasmin    safed   telupu   white

# %%
df=df[df.english=="red"]

# %%
df
# Out:
#   flowersnames hindi telugu english
# 0         rose  laal  erupu     red
# 2     hibiscus  laal  erupu     red

# %%
df=df[df.english=="white"]
df
# Out:
#   flowersnames  hindi  telugu english
# 1        lilly  safed  telupu   white
# 5       jasmin  safed  telupu   white

# %%
df=df[df.english=="pink"]
df
# Out:
#   flowersnames    hindi   telugu english
# 4        lotus  gulaabi  gulaabi    pink

# %%
lst=["red","white"]
df=df[~df["english"].isin(lst)]
df
# Out:
#   flowersnames    hindi   telugu english
# 3    sunflower    peela   pasupu  yellow
# 4        lotus  gulaabi  gulaabi    pink

# %%
lst=["red","pink"]
df=df[df["english"].isin(lst)]
df
# Out:
#   flowersnames    hindi   telugu english
# 0         rose     laal    erupu     red
# 2     hibiscus     laal    erupu     red
# 4        lotus  gulaabi  gulaabi    pink
