# %%
import pandas as pd
BBB_Patient=pd.read_excel(r"C:\Users\HP\Downloads\Insurance_Customers (1).xlsx",sheet_name="BBB_Patients")
BBB_Patient
# Out:
#        patientid  membershipid    groupid   person_nbr
# 0          10001     123456891  Upperbody  2386.041022
# 1          10002     123456891  Upperbody  7219.568003
# 2          10003     123456891  Upperbody  1110.167181
# 3          10004     123456891  Upperbody  4522.639998
# 4          10005     123456891  Upperbody  7305.192980
# ...          ...           ...        ...          ...
# 10114      20115     123456896     Nerves  2985.574310
# 10115      20116     123456896     Nerves  9698.888692
# 10116      20117     123456896     Nerves  3305.456074
# 10117      20118     123456896     Nerves  9179.853623
# 10118      20119     123456896     Nerves  2048.429434
#
# [10119 rows x 4 columns]

# %%
# basic checks

# %%
BBB_Patient.head()
# Out:
#    patientid  membershipid    groupid   person_nbr
# 0      10001     123456891  Upperbody  2386.041022
# 1      10002     123456891  Upperbody  7219.568003
# 2      10003     123456891  Upperbody  1110.167181
# 3      10004     123456891  Upperbody  4522.639998
# 4      10005     123456891  Upperbody  7305.192980

# %%
BBB_Patient.tail()
# Out:
#        patientid  membershipid groupid   person_nbr
# 10114      20115     123456896  Nerves  2985.574310
# 10115      20116     123456896  Nerves  9698.888692
# 10116      20117     123456896  Nerves  3305.456074
# 10117      20118     123456896  Nerves  9179.853623
# 10118      20119     123456896  Nerves  2048.429434

# %%
BBB_Patient.columns
# Out:
# Index(['patientid', 'membershipid', 'groupid', 'person_nbr'], dtype='object')

# %%
BBB_Patient.shape
# Out:
# (10119, 4)

# %%
# import bbb address files

# %%
import pandas as pd
BBB_Address=pd.read_excel(r"C:\Users\HP\Downloads\Insurance_Customers (1).xlsx",sheet_name="BBB_Address")
BBB_Address
# Out:
#        patientid  membershipid    groupid    person_nbr Primary_Phone_NBR  \
# 0          10001     123456891  Upperbody  2.386041e+03                 C
# 1          10002     123456891  Upperbody  7.219568e+03                 C
# 2          10003     123456891  Upperbody  1.110167e+03                 C
# 3          10004     123456891  Upperbody  4.522640e+03                 C
# 4          10005     123456891  Upperbody  7.305193e+03                 C
# ...          ...           ...        ...           ...               ...
# 15989      25990      28862324       EarD  4.315597e+06                 C
# 15990      25991      46570001       EarD  9.763304e+06                 C
# 15991      25992      26399463       EarD  1.137260e+07                 C
# 15992      25993      63512490       EarD  1.228728e+07                 C
# 15993      25994      30518036       EarD  3.797032e+06                 C
#
#       Phone2_NBR Phone3_NBR
# 0              O          C
# ...

# %%
# basic cheks

# %%
BBB_Address.shape
# Out:
# (15994, 7)

# %%
BBB_Address.columns
# Out:
# Index(['patientid', 'membershipid', 'groupid', 'person_nbr',
#        'Primary_Phone_NBR', 'Phone2_NBR', 'Phone3_NBR'],
#       dtype='object')

# %%
BBB_Address.head()
# Out:
#    patientid  membershipid    groupid   person_nbr Primary_Phone_NBR  \
# 0      10001     123456891  Upperbody  2386.041022                 C
# 1      10002     123456891  Upperbody  7219.568003                 C
# 2      10003     123456891  Upperbody  1110.167181                 C
# 3      10004     123456891  Upperbody  4522.639998                 C
# 4      10005     123456891  Upperbody  7305.192980                 C
#
#   Phone2_NBR Phone3_NBR
# 0          O          C
# 1          O          C
# 2          O          C
# 3          O          C
# 4          O          C

# %%
BBB_Address.tail()
# Out:
#        patientid  membershipid groupid    person_nbr Primary_Phone_NBR  \
# 15989      25990      28862324    EarD  4.315597e+06                 C
# 15990      25991      46570001    EarD  9.763304e+06                 C
# 15991      25992      26399463    EarD  1.137260e+07                 C
# 15992      25993      63512490    EarD  1.228728e+07                 C
# 15993      25994      30518036    EarD  3.797032e+06                 C
#
#       Phone2_NBR Phone3_NBR
# 15989          H          C
# 15990          H          C
# 15991          H          C
# 15992          H          C
# 15993          H          C

# %%
# left join

# %%
BBB_left=BBB_Patient.merge(BBB_Address,how="left",on=["patientid","membershipid","groupid","person_nbr"])
BBB_left
# Out:
#        patientid  membershipid    groupid   person_nbr Primary_Phone_NBR  \
# 0          10001     123456891  Upperbody  2386.041022                 C
# 1          10002     123456891  Upperbody  7219.568003                 C
# 2          10003     123456891  Upperbody  1110.167181                 C
# 3          10004     123456891  Upperbody  4522.639998                 C
# 4          10005     123456891  Upperbody  7305.192980                 C
# ...          ...           ...        ...          ...               ...
# 10114      20115     123456896     Nerves  2985.574310                 C
# 10115      20116     123456896     Nerves  9698.888692                 C
# 10116      20117     123456896     Nerves  3305.456074                 C
# 10117      20118     123456896     Nerves  9179.853623                 C
# 10118      20119     123456896     Nerves  2048.429434                 C
#
#       Phone2_NBR Phone3_NBR
# 0              O          C
# 1              O          C
# ...

# %%
BBB_left.columns
# Out:
# Index(['patientid', 'membershipid', 'groupid', 'person_nbr',
#        'Primary_Phone_NBR', 'Phone2_NBR', 'Phone3_NBR'],
#       dtype='object')

# %%
cell_flag=""
BBB_left["cell_flag"]=cell_flag
BBB_left
# Out:
#        patientid  membershipid    groupid   person_nbr Primary_Phone_NBR  \
# 0          10001     123456891  Upperbody  2386.041022                 C
# 1          10002     123456891  Upperbody  7219.568003                 C
# 2          10003     123456891  Upperbody  1110.167181                 C
# 3          10004     123456891  Upperbody  4522.639998                 C
# 4          10005     123456891  Upperbody  7305.192980                 C
# ...          ...           ...        ...          ...               ...
# 10114      20115     123456896     Nerves  2985.574310                 C
# 10115      20116     123456896     Nerves  9698.888692                 C
# 10116      20117     123456896     Nerves  3305.456074                 C
# 10117      20118     123456896     Nerves  9179.853623                 C
# 10118      20119     123456896     Nerves  2048.429434                 C
#
#       Phone2_NBR Phone3_NBR cell_flag
# 0              O          C
# ...

# %%
import numpy as np

# %%
BBB_left["cell_flag"]=np.where(BBB_left["Primary_Phone_NBR"]=="C","P",BBB_left["cell_flag"])
BBB_left
# Out:
#        patientid  membershipid    groupid   person_nbr Primary_Phone_NBR  \
# 0          10001     123456891  Upperbody  2386.041022                 C
# 1          10002     123456891  Upperbody  7219.568003                 C
# 2          10003     123456891  Upperbody  1110.167181                 C
# 3          10004     123456891  Upperbody  4522.639998                 C
# 4          10005     123456891  Upperbody  7305.192980                 C
# ...          ...           ...        ...          ...               ...
# 10114      20115     123456896     Nerves  2985.574310                 C
# 10115      20116     123456896     Nerves  9698.888692                 C
# 10116      20117     123456896     Nerves  3305.456074                 C
# 10117      20118     123456896     Nerves  9179.853623                 C
# 10118      20119     123456896     Nerves  2048.429434                 C
#
#       Phone2_NBR Phone3_NBR cell_flag
# 0              O          C         P
# ...

# %%
BBB_left.cell_flag.unique()
# Out:
# array(['P', ''], dtype=object)

# %%
BBB_left.cell_flag.value_counts()
# Out:
#      6372
# P    3747
# Name: cell_flag, dtype: int64

# %%
BBB_left["cell_flag"]=np.where(BBB_left["Primary_Phone_NBR"]!="C","S",BBB_left["cell_flag"])
BBB_left
# Out:
#        patientid  membershipid    groupid   person_nbr Primary_Phone_NBR  \
# 0          10001     123456891  Upperbody  2386.041022                 C
# 1          10002     123456891  Upperbody  7219.568003                 C
# 2          10003     123456891  Upperbody  1110.167181                 C
# 3          10004     123456891  Upperbody  4522.639998                 C
# 4          10005     123456891  Upperbody  7305.192980                 C
# ...          ...           ...        ...          ...               ...
# 10114      20115     123456896     Nerves  2985.574310                 C
# 10115      20116     123456896     Nerves  9698.888692                 C
# 10116      20117     123456896     Nerves  3305.456074                 C
# 10117      20118     123456896     Nerves  9179.853623                 C
# 10118      20119     123456896     Nerves  2048.429434                 C
#
#       Phone2_NBR Phone3_NBR cell_flag
# 0              O          C         P
# ...

# %%
BBB_left.cell_flag.unique()
# Out:
# array(['P', 'S'], dtype=object)

# %%
BBB_left.cell_flag.value_counts()
# Out:
# S    6372
# P    3747
# Name: cell_flag, dtype: int64

# %%
lst=["C","O","H"]

# %%
BBB_left["cell_flag"]=np.where(~BBB_left["Primary_Phone_NBR"].isin(lst),"N",BBB_left["cell_flag"])
BBB_left
# Out:
#        patientid  membershipid    groupid   person_nbr Primary_Phone_NBR  \
# 0          10001     123456891  Upperbody  2386.041022                 C
# 1          10002     123456891  Upperbody  7219.568003                 C
# 2          10003     123456891  Upperbody  1110.167181                 C
# 3          10004     123456891  Upperbody  4522.639998                 C
# 4          10005     123456891  Upperbody  7305.192980                 C
# ...          ...           ...        ...          ...               ...
# 10114      20115     123456896     Nerves  2985.574310                 C
# 10115      20116     123456896     Nerves  9698.888692                 C
# 10116      20117     123456896     Nerves  3305.456074                 C
# 10117      20118     123456896     Nerves  9179.853623                 C
# 10118      20119     123456896     Nerves  2048.429434                 C
#
#       Phone2_NBR Phone3_NBR cell_flag
# 0              O          C         P
# ...

# %%
BBB_left.cell_flag.unique()
# Out:
# array(['P', 'S', 'N'], dtype=object)

# %%
BBB_left.cell_flag.value_counts()
# Out:
# S    6202
# P    3747
# N     170
# Name: cell_flag, dtype: int64

# %%
BBB_left["Flag"]=""
BBB_left
# Out:
#        patientid  membershipid    groupid   person_nbr Primary_Phone_NBR  \
# 0          10001     123456891  Upperbody  2386.041022                 C
# 1          10002     123456891  Upperbody  7219.568003                 C
# 2          10003     123456891  Upperbody  1110.167181                 C
# 3          10004     123456891  Upperbody  4522.639998                 C
# 4          10005     123456891  Upperbody  7305.192980                 C
# ...          ...           ...        ...          ...               ...
# 10114      20115     123456896     Nerves  2985.574310                 C
# 10115      20116     123456896     Nerves  9698.888692                 C
# 10116      20117     123456896     Nerves  3305.456074                 C
# 10117      20118     123456896     Nerves  9179.853623                 C
# 10118      20119     123456896     Nerves  2048.429434                 C
#
#       Phone2_NBR Phone3_NBR cell_flag Flag
# 0              O          C         P
# ...

# %%
BBB_left["Flag"]="total BBB_Patients"
BBB_left
# Out:
#        patientid  membershipid    groupid   person_nbr Primary_Phone_NBR  \
# 0          10001     123456891  Upperbody  2386.041022                 C
# 1          10002     123456891  Upperbody  7219.568003                 C
# 2          10003     123456891  Upperbody  1110.167181                 C
# 3          10004     123456891  Upperbody  4522.639998                 C
# 4          10005     123456891  Upperbody  7305.192980                 C
# ...          ...           ...        ...          ...               ...
# 10114      20115     123456896     Nerves  2985.574310                 C
# 10115      20116     123456896     Nerves  9698.888692                 C
# 10116      20117     123456896     Nerves  3305.456074                 C
# 10117      20118     123456896     Nerves  9179.853623                 C
# 10118      20119     123456896     Nerves  2048.429434                 C
#
#       Phone2_NBR Phone3_NBR cell_flag                Flag
# ...

# %%
BBB_left.columns
# Out:
# Index(['patientid', 'membershipid', 'groupid', 'person_nbr',
#        'Primary_Phone_NBR', 'Phone2_NBR', 'Phone3_NBR', 'cell_flag', 'Flag'],
#       dtype='object')

# %%
BBB_left_P=BBB_left[BBB_left.cell_flag=="P"]

# %%
BBB_left_P["Flag"]="Total BBB patients for cell_flag P"
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5064\1937052507.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BBB_left_P["Flag"]="Total BBB patients for cell_flag P"

# %%
BBB_left_S=BBB_left[BBB_left.cell_flag=="S"]

# %%
BBB_left_S["Flag"]="Total BBB patients for cell_flag S"
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5064\4056500358.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BBB_left_S["Flag"]="Total BBB patients for cell_flag S"

# %%
BBB_left_N=BBB_left[BBB_left.cell_flag=="N"]

# %%
BBB_left_N["Flag"]="Total BBB patients for cell_flag N"
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5064\1568941468.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BBB_left_N["Flag"]="Total BBB patients for cell_flag N"

# %%
BBB_left_N.head()
# Out:
#       patientid  membershipid groupid   person_nbr Primary_Phone_NBR  \
# 3036      13037     123456891    LegF  9447.678446               NaN
# 3037      13038     123456891    LegF  3437.111516               NaN
# 3038      13039     123456891    LegF  7779.922222               NaN
# 3039      13040     123456891    LegF  5906.645817               NaN
# 3040      13041     123456891    LegF  3847.111009               NaN
#
#      Phone2_NBR Phone3_NBR cell_flag                                Flag
# 3036        NaN        NaN         N  Total BBB patients for cell_flag N
# 3037        NaN        NaN         N  Total BBB patients for cell_flag N
# 3038        NaN        NaN         N  Total BBB patients for cell_flag N
# 3039        NaN        NaN         N  Total BBB patients for cell_flag N
# 3040        NaN        NaN         N  Total BBB patients for cell_flag N

# %%
BBB_left_P.head()
# Out:
#    patientid  membershipid    groupid   person_nbr Primary_Phone_NBR  \
# 0      10001     123456891  Upperbody  2386.041022                 C
# 1      10002     123456891  Upperbody  7219.568003                 C
# 2      10003     123456891  Upperbody  1110.167181                 C
# 3      10004     123456891  Upperbody  4522.639998                 C
# 4      10005     123456891  Upperbody  7305.192980                 C
#
#   Phone2_NBR Phone3_NBR cell_flag                                Flag
# 0          O          C         P  Total BBB patients for cell_flag P
# 1          O          C         P  Total BBB patients for cell_flag P
# 2          O          C         P  Total BBB patients for cell_flag P
# 3          O          C         P  Total BBB patients for cell_flag P
# 4          O          C         P  Total BBB patients for cell_flag P

# %%
BBB_left_S.tail()
# Out:
#       patientid  membershipid  groupid   person_nbr Primary_Phone_NBR  \
# 7187      17188     123456895  Obesity  9565.025227                 O
# 7188      17189     123456895  Obesity  4904.301854                 O
# 7189      17190     123456895  Obesity  1480.185813                 O
# 7190      17191     123456895  Obesity  4421.445047                 O
# 7191      17192     123456895  Obesity  8054.137283                 O
#
#      Phone2_NBR Phone3_NBR cell_flag                                Flag
# 7187          H          C         S  Total BBB patients for cell_flag S
# 7188          H          C         S  Total BBB patients for cell_flag S
# 7189          H          C         S  Total BBB patients for cell_flag S
# 7190          H          C         S  Total BBB patients for cell_flag S
# 7191          H          C         S  Total BBB patients for cell_flag S

# %%
BBB_left_S.head()
# Out:
#      patientid  membershipid    groupid   person_nbr Primary_Phone_NBR  \
# 614      10615     123456891  Lowerbody  3303.046210                 O
# 615      10616     123456891  Lowerbody  4080.627852                 O
# 616      10617     123456891  Lowerbody  4888.358478                 O
# 617      10618     123456891  Lowerbody  9764.582779                 O
# 618      10619     123456891  Lowerbody  7557.726735                 O
#
#     Phone2_NBR Phone3_NBR cell_flag                                Flag
# 614          C          O         S  Total BBB patients for cell_flag S
# 615          C          O         S  Total BBB patients for cell_flag S
# 616          C          O         S  Total BBB patients for cell_flag S
# 617          C          O         S  Total BBB patients for cell_flag S
# 618          C          O         S  Total BBB patients for cell_flag S

# %%
BBB_left_N.head()
# Out:
#       patientid  membershipid groupid   person_nbr Primary_Phone_NBR  \
# 3036      13037     123456891    LegF  9447.678446               NaN
# 3037      13038     123456891    LegF  3437.111516               NaN
# 3038      13039     123456891    LegF  7779.922222               NaN
# 3039      13040     123456891    LegF  5906.645817               NaN
# 3040      13041     123456891    LegF  3847.111009               NaN
#
#      Phone2_NBR Phone3_NBR cell_flag                                Flag
# 3036        NaN        NaN         N  Total BBB patients for cell_flag N
# 3037        NaN        NaN         N  Total BBB patients for cell_flag N
# 3038        NaN        NaN         N  Total BBB patients for cell_flag N
# 3039        NaN        NaN         N  Total BBB patients for cell_flag N
# 3040        NaN        NaN         N  Total BBB patients for cell_flag N

# %%
#BBB_left,BBB_left_P,BBB_left_S,BBB_left_N

# %%
BBB_left_sm=BBB_left.groupby(["Flag"])["patientid"].count()
BBB_left_sm_ndf=pd.DataFrame(BBB_left_sm)
BBB_left_sm_ndf.reset_index(inplace=True)

# %%
BBB_left_sm_ndf
# Out:
#                  Flag  patientid
# 0  total BBB_Patients      10119

# %%
BBB_left_P_sm=BBB_left_P.groupby(["Flag"])["patientid"].count()
BBB_left_P_sm
# Out:
# Flag
# Total BBB patients for cell_flag P    3747
# Name: patientid, dtype: int64

# %%
BBB_left_P_sm=BBB_left_P.groupby(["Flag"])["patientid"].count()
BBB_left_P_sm_ndf=pd.DataFrame(BBB_left_P_sm)
BBB_left_P_sm_ndf.reset_index(inplace=True)

# %%
BBB_left_P_sm_ndf
# Out:
#                                  Flag  patientid
# 0  Total BBB patients for cell_flag P       3747

# %%
BBB_left_S_sm=BBB_left_S.groupby(["Flag"])["patientid"].count()
BBB_left_S_sm_ndf=pd.DataFrame(BBB_left_S_sm)
BBB_left_S_sm_ndf.reset_index(inplace=True)

# %%
BBB_left_S_sm_ndf
# Out:
#                                  Flag  patientid
# 0  Total BBB patients for cell_flag S       6202

# %%
BBB_left_N_sm=BBB_left_N.groupby(["Flag"])["patientid"].count()
BBB_left_N_sm_ndf=pd.DataFrame(BBB_left_N_sm)
BBB_left_N_sm_ndf.reset_index(inplace=True)

# %%
BBB_left_N_sm_ndf
# Out:
#                                  Flag  patientid
# 0  Total BBB patients for cell_flag N        170

# %%
# append
#BBB_left_N_sm_ndf
import pandas as pd
final_df1=pd.concat([BBB_left_sm_ndf,BBB_left_P_sm_ndf,BBB_left_S_sm_ndf,BBB_left_N_sm_ndf],ignore_index=True,axis=0)
final_df1
# Out:
#                                  Flag  patientid
# 0                  total BBB_Patients      10119
# 1  Total BBB patients for cell_flag P       3747
# 2  Total BBB patients for cell_flag S       6202
# 3  Total BBB patients for cell_flag N        170

# %%
final_df1.columns=["Flag","Count"]
final_df1
# Out:
#                                  Flag  Count
# 0                  total BBB_Patients  10119
# 1  Total BBB patients for cell_flag P   3747
# 2  Total BBB patients for cell_flag S   6202
# 3  Total BBB patients for cell_flag N    170

# %%
import pandas as pd
df1=pd.DataFrame()
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import time
now=time.localtime()
t=time.strftime("%H : %M : %S,",now)
print(t)
# Out:
# 16 : 57 : 39,

# %%
t
# Out:
# '16 : 57 : 39,'

# %%
from datetime import date
today=date.today()
print("today=",today)
# Out:
# today= 2023-08-29

# %%
today
# Out:
# datetime.date(2023, 8, 29)

# %%
final_df1["Time"]=t
final_df1["Date"]=today

# %%
final_df1.columns=["Date","Time","Flag","Count"]
final_df1
# Out:
#                                  Date   Time           Flag       Count
# 0                  total BBB_Patients  10119  16 : 57 : 39,  2023-08-29
# 1  Total BBB patients for cell_flag P   3747  16 : 57 : 39,  2023-08-29
# 2  Total BBB patients for cell_flag S   6202  16 : 57 : 39,  2023-08-29
# 3  Total BBB patients for cell_flag N    170  16 : 57 : 39,  2023-08-29

# %%
final_df1
# Out:
#                                  Date   Time           Flag       Count
# 0                  total BBB_Patients  10119  16 : 57 : 39,  2023-08-29
# 1  Total BBB patients for cell_flag P   3747  16 : 57 : 39,  2023-08-29
# 2  Total BBB patients for cell_flag S   6202  16 : 57 : 39,  2023-08-29
# 3  Total BBB patients for cell_flag N    170  16 : 57 : 39,  2023-08-29

# %%
import pandas as pd
BBB_Patients=pd.read_excel(r"C:\Users\HP\Downloads\Insurance_Customers (1).xlsx",sheet_name="BBB_Patients")
BBB_Patients
# Out:
#        patientid  membershipid    groupid   person_nbr
# 0          10001     123456891  Upperbody  2386.041022
# 1          10002     123456891  Upperbody  7219.568003
# 2          10003     123456891  Upperbody  1110.167181
# 3          10004     123456891  Upperbody  4522.639998
# 4          10005     123456891  Upperbody  7305.192980
# ...          ...           ...        ...          ...
# 10114      20115     123456896     Nerves  2985.574310
# 10115      20116     123456896     Nerves  9698.888692
# 10116      20117     123456896     Nerves  3305.456074
# 10117      20118     123456896     Nerves  9179.853623
# 10118      20119     123456896     Nerves  2048.429434
#
# [10119 rows x 4 columns]

# %%
BBB_Patients.head()
# Out:
#    patientid  membershipid    groupid   person_nbr
# 0      10001     123456891  Upperbody  2386.041022
# 1      10002     123456891  Upperbody  7219.568003
# 2      10003     123456891  Upperbody  1110.167181
# 3      10004     123456891  Upperbody  4522.639998
# 4      10005     123456891  Upperbody  7305.192980

# %%
BBB_Patients.tail()
# Out:
#        patientid  membershipid groupid   person_nbr
# 10114      20115     123456896  Nerves  2985.574310
# 10115      20116     123456896  Nerves  9698.888692
# 10116      20117     123456896  Nerves  3305.456074
# 10117      20118     123456896  Nerves  9179.853623
# 10118      20119     123456896  Nerves  2048.429434

# %%
BBB_Patients.columns
# Out:
# Index(['patientid', 'membershipid', 'groupid', 'person_nbr'], dtype='object')

# %%
BBB_Patients.shape
# Out:
# (10119, 4)

# %%
import pandas as pd
BBB_Address=pd.read_excel(r"C:\Users\HP\Downloads\Insurance_Customers (1).xlsx",sheet_name="BBB_Address")
BBB_Address
# Out:
#        patientid  membershipid    groupid    person_nbr Primary_Phone_NBR  \
# 0          10001     123456891  Upperbody  2.386041e+03                 C
# 1          10002     123456891  Upperbody  7.219568e+03                 C
# 2          10003     123456891  Upperbody  1.110167e+03                 C
# 3          10004     123456891  Upperbody  4.522640e+03                 C
# 4          10005     123456891  Upperbody  7.305193e+03                 C
# ...          ...           ...        ...           ...               ...
# 15989      25990      28862324       EarD  4.315597e+06                 C
# 15990      25991      46570001       EarD  9.763304e+06                 C
# 15991      25992      26399463       EarD  1.137260e+07                 C
# 15992      25993      63512490       EarD  1.228728e+07                 C
# 15993      25994      30518036       EarD  3.797032e+06                 C
#
#       Phone2_NBR Phone3_NBR
# 0              O          C
# ...

# %%
BBB_Address.head()
# Out:
#    patientid  membershipid    groupid   person_nbr Primary_Phone_NBR  \
# 0      10001     123456891  Upperbody  2386.041022                 C
# 1      10002     123456891  Upperbody  7219.568003                 C
# 2      10003     123456891  Upperbody  1110.167181                 C
# 3      10004     123456891  Upperbody  4522.639998                 C
# 4      10005     123456891  Upperbody  7305.192980                 C
#
#   Phone2_NBR Phone3_NBR
# 0          O          C
# 1          O          C
# 2          O          C
# 3          O          C
# 4          O          C

# %%
BBB_Address.tail()
# Out:
#        patientid  membershipid groupid    person_nbr Primary_Phone_NBR  \
# 15989      25990      28862324    EarD  4.315597e+06                 C
# 15990      25991      46570001    EarD  9.763304e+06                 C
# 15991      25992      26399463    EarD  1.137260e+07                 C
# 15992      25993      63512490    EarD  1.228728e+07                 C
# 15993      25994      30518036    EarD  3.797032e+06                 C
#
#       Phone2_NBR Phone3_NBR
# 15989          H          C
# 15990          H          C
# 15991          H          C
# 15992          H          C
# 15993          H          C

# %%
BBB_Address.columns
# Out:
# Index(['patientid', 'membershipid', 'groupid', 'person_nbr',
#        'Primary_Phone_NBR', 'Phone2_NBR', 'Phone3_NBR'],
#       dtype='object')

# %%
BBB_Address.index
# Out:
# RangeIndex(start=0, stop=15994, step=1)

# %%
BBB_Address.shape
# Out:
# (15994, 7)

# %%
##leftjoin

# %%
BBB_Patients_left_m=BBB_Patients.merge(BBB_Address,how="left",on=["patientid","membershipid","groupid"])
BBB_Patients_left_m
# Out:
#        patientid  membershipid    groupid  person_nbr_x  person_nbr_y  \
# 0          10001     123456891  Upperbody   2386.041022   2386.041022
# 1          10002     123456891  Upperbody   7219.568003   7219.568003
# 2          10003     123456891  Upperbody   1110.167181   1110.167181
# 3          10004     123456891  Upperbody   4522.639998   4522.639998
# 4          10005     123456891  Upperbody   7305.192980   7305.192980
# ...          ...           ...        ...           ...           ...
# 10114      20115     123456896     Nerves   2985.574310   2985.574310
# 10115      20116     123456896     Nerves   9698.888692   9698.888692
# 10116      20117     123456896     Nerves   3305.456074   3305.456074
# 10117      20118     123456896     Nerves   9179.853623   9179.853623
# 10118      20119     123456896     Nerves   2048.429434   2048.429434
#
#       Primary_Phone_NBR Phone2_NBR Phone3_NBR
# 0                     C          O          C
# ...

# %%
BBB_Patients_left_m["cell_flag"]=" "
BBB_Patients_left_m
# Out:
#        patientid  membershipid    groupid  person_nbr_x  person_nbr_y  \
# 0          10001     123456891  Upperbody   2386.041022   2386.041022
# 1          10002     123456891  Upperbody   7219.568003   7219.568003
# 2          10003     123456891  Upperbody   1110.167181   1110.167181
# 3          10004     123456891  Upperbody   4522.639998   4522.639998
# 4          10005     123456891  Upperbody   7305.192980   7305.192980
# ...          ...           ...        ...           ...           ...
# 10114      20115     123456896     Nerves   2985.574310   2985.574310
# 10115      20116     123456896     Nerves   9698.888692   9698.888692
# 10116      20117     123456896     Nerves   3305.456074   3305.456074
# 10117      20118     123456896     Nerves   9179.853623   9179.853623
# 10118      20119     123456896     Nerves   2048.429434   2048.429434
#
#       Primary_Phone_NBR Phone2_NBR Phone3_NBR cell_flag
# 0                     C          O          C
# ...

# %%
import numpy as np

# %%
BBB_Patients_left_m["cell_flag"]=np.where(BBB_Patients_left_m["Primary_Phone_NBR"]=="C","P",BBB_Patients_left_m["cell_flag"])
BBB_Patients_left_m
# Out:
#        patientid  membershipid    groupid  person_nbr_x  person_nbr_y  \
# 0          10001     123456891  Upperbody   2386.041022   2386.041022
# 1          10002     123456891  Upperbody   7219.568003   7219.568003
# 2          10003     123456891  Upperbody   1110.167181   1110.167181
# 3          10004     123456891  Upperbody   4522.639998   4522.639998
# 4          10005     123456891  Upperbody   7305.192980   7305.192980
# ...          ...           ...        ...           ...           ...
# 10114      20115     123456896     Nerves   2985.574310   2985.574310
# 10115      20116     123456896     Nerves   9698.888692   9698.888692
# 10116      20117     123456896     Nerves   3305.456074   3305.456074
# 10117      20118     123456896     Nerves   9179.853623   9179.853623
# 10118      20119     123456896     Nerves   2048.429434   2048.429434
#
#       Primary_Phone_NBR Phone2_NBR Phone3_NBR cell_flag
# 0                     C          O          C         P
# ...

# %%
BBB_Patients_left_m.cell_flag.unique()
# Out:
# array(['P', ' '], dtype=object)

# %%
BBB_Patients_left_m["cell_flag"]=np.where(BBB_Patients_left_m["Primary_Phone_NBR"]!="C","S",BBB_Patients_left_m["cell_flag"])
BBB_Patients_left_m
# Out:
#        patientid  membershipid    groupid  person_nbr_x  person_nbr_y  \
# 0          10001     123456891  Upperbody   2386.041022   2386.041022
# 1          10002     123456891  Upperbody   7219.568003   7219.568003
# 2          10003     123456891  Upperbody   1110.167181   1110.167181
# 3          10004     123456891  Upperbody   4522.639998   4522.639998
# 4          10005     123456891  Upperbody   7305.192980   7305.192980
# ...          ...           ...        ...           ...           ...
# 10114      20115     123456896     Nerves   2985.574310   2985.574310
# 10115      20116     123456896     Nerves   9698.888692   9698.888692
# 10116      20117     123456896     Nerves   3305.456074   3305.456074
# 10117      20118     123456896     Nerves   9179.853623   9179.853623
# 10118      20119     123456896     Nerves   2048.429434   2048.429434
#
#       Primary_Phone_NBR Phone2_NBR Phone3_NBR cell_flag
# 0                     C          O          C         P
# ...

# %%
BBB_Patients_left_m.cell_flag.unique()
# Out:
# array(['P', 'S'], dtype=object)

# %%
lst=["C","O","H"]

# %%
BBB_Patients_left_m["cell_flag"]=np.where(~BBB_Patients_left_m["Primary_Phone_NBR"].isin(lst),"N",BBB_Patients_left_m["cell_flag"])
BBB_Patients_left_m
# Out:
#        patientid  membershipid    groupid  person_nbr_x  person_nbr_y  \
# 0          10001     123456891  Upperbody   2386.041022   2386.041022
# 1          10002     123456891  Upperbody   7219.568003   7219.568003
# 2          10003     123456891  Upperbody   1110.167181   1110.167181
# 3          10004     123456891  Upperbody   4522.639998   4522.639998
# 4          10005     123456891  Upperbody   7305.192980   7305.192980
# ...          ...           ...        ...           ...           ...
# 10114      20115     123456896     Nerves   2985.574310   2985.574310
# 10115      20116     123456896     Nerves   9698.888692   9698.888692
# 10116      20117     123456896     Nerves   3305.456074   3305.456074
# 10117      20118     123456896     Nerves   9179.853623   9179.853623
# 10118      20119     123456896     Nerves   2048.429434   2048.429434
#
#       Primary_Phone_NBR Phone2_NBR Phone3_NBR cell_flag
# 0                     C          O          C         P
# ...

# %%
BBB_Patients_left_m.cell_flag.unique()
# Out:
# array(['P', 'S', 'N'], dtype=object)

# %%
BBB_Patients_left_m.cell_flag.value_counts()
# Out:
# S    6202
# P    3747
# N     170
# Name: cell_flag, dtype: int64

# %%
BBB_Patients_left_m["Flag"]=""
BBB_Patients_left_m
# Out:
#        patientid  membershipid    groupid  person_nbr_x  person_nbr_y  \
# 0          10001     123456891  Upperbody   2386.041022   2386.041022
# 1          10002     123456891  Upperbody   7219.568003   7219.568003
# 2          10003     123456891  Upperbody   1110.167181   1110.167181
# 3          10004     123456891  Upperbody   4522.639998   4522.639998
# 4          10005     123456891  Upperbody   7305.192980   7305.192980
# ...          ...           ...        ...           ...           ...
# 10114      20115     123456896     Nerves   2985.574310   2985.574310
# 10115      20116     123456896     Nerves   9698.888692   9698.888692
# 10116      20117     123456896     Nerves   3305.456074   3305.456074
# 10117      20118     123456896     Nerves   9179.853623   9179.853623
# 10118      20119     123456896     Nerves   2048.429434   2048.429434
#
#       Primary_Phone_NBR Phone2_NBR Phone3_NBR cell_flag Flag
# 0                     C          O          C         P
# ...

# %%
BBB_Patients_left_m["Flag"]="Total BBB Patients"
BBB_Patients_left_m
# Out:
#        patientid  membershipid    groupid  person_nbr_x  person_nbr_y  \
# 0          10001     123456891  Upperbody   2386.041022   2386.041022
# 1          10002     123456891  Upperbody   7219.568003   7219.568003
# 2          10003     123456891  Upperbody   1110.167181   1110.167181
# 3          10004     123456891  Upperbody   4522.639998   4522.639998
# 4          10005     123456891  Upperbody   7305.192980   7305.192980
# ...          ...           ...        ...           ...           ...
# 10114      20115     123456896     Nerves   2985.574310   2985.574310
# 10115      20116     123456896     Nerves   9698.888692   9698.888692
# 10116      20117     123456896     Nerves   3305.456074   3305.456074
# 10117      20118     123456896     Nerves   9179.853623   9179.853623
# 10118      20119     123456896     Nerves   2048.429434   2048.429434
#
#       Primary_Phone_NBR Phone2_NBR Phone3_NBR cell_flag                Flag
# ...

# %%
BBB_Patients_left_m.columns
# Out:
# Index(['patientid', 'membershipid', 'groupid', 'person_nbr_x', 'person_nbr_y',
#        'Primary_Phone_NBR', 'Phone2_NBR', 'Phone3_NBR', 'cell_flag', 'Flag'],
#       dtype='object')

# %%
BBB_Patients_left_m_filter=BBB_Patients_left_m[['patientid', 'membershipid', 'groupid', 'person_nbr_x', 
       'Primary_Phone_NBR', 'Phone2_NBR', 'Phone3_NBR', 'cell_flag', 'Flag']]

# %%
BBB_Patients_left_m_filter
# Out:
#        patientid  membershipid    groupid  person_nbr_x Primary_Phone_NBR  \
# 0          10001     123456891  Upperbody   2386.041022                 C
# 1          10002     123456891  Upperbody   7219.568003                 C
# 2          10003     123456891  Upperbody   1110.167181                 C
# 3          10004     123456891  Upperbody   4522.639998                 C
# 4          10005     123456891  Upperbody   7305.192980                 C
# ...          ...           ...        ...           ...               ...
# 10114      20115     123456896     Nerves   2985.574310                 C
# 10115      20116     123456896     Nerves   9698.888692                 C
# 10116      20117     123456896     Nerves   3305.456074                 C
# 10117      20118     123456896     Nerves   9179.853623                 C
# 10118      20119     123456896     Nerves   2048.429434                 C
#
#       Phone2_NBR Phone3_NBR cell_flag                Flag
# ...

# %%
BBB_Patients_left_m_P=BBB_Patients_left_m_filter[BBB_Patients_left_m_filter.cell_flag=="P"]

# %%
BBB_Patients_left_m_P["Flag"]="Total BBB Patients for cell_flag P"
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5064\2902359505.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BBB_Patients_left_m_P["Flag"]="Total BBB Patients for cell_flag P"

# %%
BBB_Patients_left_m_P
# Out:
#        patientid  membershipid    groupid  person_nbr_x Primary_Phone_NBR  \
# 0          10001     123456891  Upperbody   2386.041022                 C
# 1          10002     123456891  Upperbody   7219.568003                 C
# 2          10003     123456891  Upperbody   1110.167181                 C
# 3          10004     123456891  Upperbody   4522.639998                 C
# 4          10005     123456891  Upperbody   7305.192980                 C
# ...          ...           ...        ...           ...               ...
# 10114      20115     123456896     Nerves   2985.574310                 C
# 10115      20116     123456896     Nerves   9698.888692                 C
# 10116      20117     123456896     Nerves   3305.456074                 C
# 10117      20118     123456896     Nerves   9179.853623                 C
# 10118      20119     123456896     Nerves   2048.429434                 C
#
#       Phone2_NBR Phone3_NBR cell_flag                                Flag
# ...

# %%
BBB_Patients_left_m_P.head()
# Out:
#    patientid  membershipid    groupid  person_nbr_x Primary_Phone_NBR  \
# 0      10001     123456891  Upperbody   2386.041022                 C
# 1      10002     123456891  Upperbody   7219.568003                 C
# 2      10003     123456891  Upperbody   1110.167181                 C
# 3      10004     123456891  Upperbody   4522.639998                 C
# 4      10005     123456891  Upperbody   7305.192980                 C
#
#   Phone2_NBR Phone3_NBR cell_flag                                Flag
# 0          O          C         P  Total BBB Patients for cell_flag P
# 1          O          C         P  Total BBB Patients for cell_flag P
# 2          O          C         P  Total BBB Patients for cell_flag P
# 3          O          C         P  Total BBB Patients for cell_flag P
# 4          O          C         P  Total BBB Patients for cell_flag P

# %%
BBB_Patients_left_m_P.tail()
# Out:
#        patientid  membershipid groupid  person_nbr_x Primary_Phone_NBR  \
# 10114      20115     123456896  Nerves   2985.574310                 C
# 10115      20116     123456896  Nerves   9698.888692                 C
# 10116      20117     123456896  Nerves   3305.456074                 C
# 10117      20118     123456896  Nerves   9179.853623                 C
# 10118      20119     123456896  Nerves   2048.429434                 C
#
#       Phone2_NBR Phone3_NBR cell_flag                                Flag
# 10114          H          C         P  Total BBB Patients for cell_flag P
# 10115          H          C         P  Total BBB Patients for cell_flag P
# 10116          H          C         P  Total BBB Patients for cell_flag P
# 10117          H          C         P  Total BBB Patients for cell_flag P
# 10118          H          C         P  Total BBB Patients for cell_flag P

# %%
BBB_Patients_left_m_S=BBB_Patients_left_m_filter[BBB_Patients_left_m_filter.cell_flag=="S"]

# %%
BBB_Patients_left_m_S["Flag"]="Total BBB Patients for cell_flag S"
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5064\2040383662.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BBB_Patients_left_m_S["Flag"]="Total BBB Patients for cell_flag S"

# %%
BBB_Patients_left_m_S
# Out:
#       patientid  membershipid    groupid  person_nbr_x Primary_Phone_NBR  \
# 614       10615     123456891  Lowerbody   3303.046210                 O
# 615       10616     123456891  Lowerbody   4080.627852                 O
# 616       10617     123456891  Lowerbody   4888.358478                 O
# 617       10618     123456891  Lowerbody   9764.582779                 O
# 618       10619     123456891  Lowerbody   7557.726735                 O
# ...         ...           ...        ...           ...               ...
# 7187      17188     123456895    Obesity   9565.025227                 O
# 7188      17189     123456895    Obesity   4904.301854                 O
# 7189      17190     123456895    Obesity   1480.185813                 O
# 7190      17191     123456895    Obesity   4421.445047                 O
# 7191      17192     123456895    Obesity   8054.137283                 O
#
#      Phone2_NBR Phone3_NBR cell_flag                                Flag
# ...

# %%
BBB_Patients_left_m_S.head()
# Out:
#      patientid  membershipid    groupid  person_nbr_x Primary_Phone_NBR  \
# 614      10615     123456891  Lowerbody   3303.046210                 O
# 615      10616     123456891  Lowerbody   4080.627852                 O
# 616      10617     123456891  Lowerbody   4888.358478                 O
# 617      10618     123456891  Lowerbody   9764.582779                 O
# 618      10619     123456891  Lowerbody   7557.726735                 O
#
#     Phone2_NBR Phone3_NBR cell_flag                                Flag
# 614          C          O         S  Total BBB Patients for cell_flag S
# 615          C          O         S  Total BBB Patients for cell_flag S
# 616          C          O         S  Total BBB Patients for cell_flag S
# 617          C          O         S  Total BBB Patients for cell_flag S
# 618          C          O         S  Total BBB Patients for cell_flag S

# %%
BBB_Patients_left_m_S.tail()
# Out:
#       patientid  membershipid  groupid  person_nbr_x Primary_Phone_NBR  \
# 7187      17188     123456895  Obesity   9565.025227                 O
# 7188      17189     123456895  Obesity   4904.301854                 O
# 7189      17190     123456895  Obesity   1480.185813                 O
# 7190      17191     123456895  Obesity   4421.445047                 O
# 7191      17192     123456895  Obesity   8054.137283                 O
#
#      Phone2_NBR Phone3_NBR cell_flag                                Flag
# 7187          H          C         S  Total BBB Patients for cell_flag S
# 7188          H          C         S  Total BBB Patients for cell_flag S
# 7189          H          C         S  Total BBB Patients for cell_flag S
# 7190          H          C         S  Total BBB Patients for cell_flag S
# 7191          H          C         S  Total BBB Patients for cell_flag S

# %%
BBB_Patients_left_m_N=BBB_Patients_left_m_filter[BBB_Patients_left_m_filter.cell_flag=="N"]

# %%
BBB_Patients_left_m_N["Flag"]="Total BBB Patients for cell_flag N"
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5064\1701427595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BBB_Patients_left_m_N["Flag"]="Total BBB Patients for cell_flag N"

# %%
BBB_Patients_left_m_N.head()
# Out:
#       patientid  membershipid groupid  person_nbr_x Primary_Phone_NBR  \
# 3036      13037     123456891    LegF   9447.678446               NaN
# 3037      13038     123456891    LegF   3437.111516               NaN
# 3038      13039     123456891    LegF   7779.922222               NaN
# 3039      13040     123456891    LegF   5906.645817               NaN
# 3040      13041     123456891    LegF   3847.111009               NaN
#
#      Phone2_NBR Phone3_NBR cell_flag                                Flag
# 3036        NaN        NaN         N  Total BBB Patients for cell_flag N
# 3037        NaN        NaN         N  Total BBB Patients for cell_flag N
# 3038        NaN        NaN         N  Total BBB Patients for cell_flag N
# 3039        NaN        NaN         N  Total BBB Patients for cell_flag N
# 3040        NaN        NaN         N  Total BBB Patients for cell_flag N

# %%
BBB_Patients_left_m_N.tail()
# Out:
#       patientid  membershipid groupid  person_nbr_x Primary_Phone_NBR  \
# 3201      13202     123456891    LegF   3193.280755               NaN
# 3202      13203     123456891    LegF     89.159800               NaN
# 3203      13204     123456891    LegF   4214.290400               NaN
# 3204      13205     123456891    LegF   5590.813250               NaN
# 3205      13206     123456891    LegF   3362.810520               NaN
#
#      Phone2_NBR Phone3_NBR cell_flag                                Flag
# 3201        NaN        NaN         N  Total BBB Patients for cell_flag N
# 3202        NaN        NaN         N  Total BBB Patients for cell_flag N
# 3203        NaN        NaN         N  Total BBB Patients for cell_flag N
# 3204        NaN        NaN         N  Total BBB Patients for cell_flag N
# 3205        NaN        NaN         N  Total BBB Patients for cell_flag N

# %%
#BBB_left,BBB_left_P,BBB_left_S,BBB_left_N

# %%
BBB_Patients_left_m_sm=BBB_Patients_left_m.groupby(["Flag"])["patientid"].count()
BBB_Patients_left_m_sm_ndf=pd.DataFrame(BBB_Patients_left_m_sm)
BBB_Patients_left_m_sm_ndf.reset_index(inplace=True)

# %%
BBB_Patients_left_m_sm_ndf
# Out:
#                  Flag  patientid
# 0  Total BBB Patients      10119

# %%
BBB_Patients_left_m_P_sm=BBB_Patients_left_m_P.groupby(["Flag"])["patientid"].count()
BBB_Patients_left_m_P_sm_ndf=pd.DataFrame(BBB_Patients_left_m_P_sm)
BBB_Patients_left_m_P_sm_ndf.reset_index(inplace=True)

# %%
BBB_Patients_left_m_P_sm_ndf
# Out:
#                                  Flag  patientid
# 0  Total BBB Patients for cell_flag P       3747

# %%
BBB_Patients_left_m_S_sm=BBB_Patients_left_m_S.groupby(["Flag"])["patientid"].count()
BBB_Patients_left_m_S_sm_ndf=pd.DataFrame(BBB_Patients_left_m_S_sm)
BBB_Patients_left_m_S_sm_ndf.reset_index(inplace=True)

# %%
BBB_Patients_left_m_S_sm_ndf
# Out:
#                                  Flag  patientid
# 0  Total BBB Patients for cell_flag S       6202

# %%
BBB_Patients_left_m_N_sm=BBB_Patients_left_m_N.groupby(["Flag"])["patientid"].count()
BBB_Patients_left_m_N_sm_ndf=pd.DataFrame(BBB_Patients_left_m_N_sm)
BBB_Patients_left_m_N_sm_ndf.reset_index(inplace=True)

# %%
BBB_Patients_left_m_N_sm_ndf
# Out:
#                                  Flag  patientid
# 0  Total BBB Patients for cell_flag N        170

# %%
# append
#BBB_left_N_sm_ndf
import pandas as pd
final_df2=pd.concat([BBB_Patients_left_m_sm_ndf,BBB_Patients_left_m_P_sm_ndf,BBB_Patients_left_m_S_sm_ndf,BBB_Patients_left_m_N_sm_ndf],ignore_index="True",axis=0)

# %%
final_df2
# Out:
# ['Date', 'Time', 'Flag', 'Count']

# %%
final_df2.columns=["Flag","Count"]
final_df2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[253], line 1
# ----> 1 final_df2.columns=["Flag","Count"]
#       2 final_df2
#
# AttributeError: 'list' object has no attribute 'columns'

# %%
import pandas as pd
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import time
now=time.localtime()
t=time.strftime("%H : %M : %S,",now)
print(t)
# Out:
# 16 : 43 : 32,

# %%
t
# Out:
# '16 : 43 : 32,'

# %%
from datetime import date
today=date.today()
print("today=",today)
# Out:
# today= 2023-08-29

# %%
today
# Out:
# datetime.date(2023, 8, 29)

# %%
final_df2["Time"]=t
final_df2["Date"]=today

# %%
####DDD_Patients import

# %%
import pandas as pd
DDD_Patients=pd.read_excel(r"C:\Users\HP\Downloads\Insurance_Customers (1).xlsx",sheet_name="DDD_Patients")
DDD_Patients
# Out:
#        patientid  membershipid  groupid   person_nbr
# 0         200001   4456.162497      100  2748.280106
# 1         200002   4456.162497      100  3983.633278
# 2         200003   4456.162497      100  5918.043203
# 3         200004   4456.162497      100  5882.418134
# 4         200005   4456.162497      100  3519.095855
# ...          ...           ...      ...          ...
# 84006     284007  61967.640577      108  6406.791285
# 84007     284008  61967.640577      108  5736.801838
# 84008     284009  61967.640577      108  7613.994822
# 84009     284010  61967.640577      108  8530.577571
# 84010     284011  61967.640577      108  2140.830791
#
# [84011 rows x 4 columns]

# %%
DDD_Patients.head()
# Out:
#    patientid  membershipid  groupid   person_nbr
# 0     200001   4456.162497      100  2748.280106
# 1     200002   4456.162497      100  3983.633278
# 2     200003   4456.162497      100  5918.043203
# 3     200004   4456.162497      100  5882.418134
# 4     200005   4456.162497      100  3519.095855

# %%
DDD_Patients.tail()
# Out:
#        patientid  membershipid  groupid   person_nbr
# 84006     284007  61967.640577      108  6406.791285
# 84007     284008  61967.640577      108  5736.801838
# 84008     284009  61967.640577      108  7613.994822
# 84009     284010  61967.640577      108  8530.577571
# 84010     284011  61967.640577      108  2140.830791

# %%
DDD_Patients.columns
# Out:
# Index(['patientid', 'membershipid', 'groupid', 'person_nbr'], dtype='object')

# %%
DDD_Patients.shape
# Out:
# (84011, 4)

# %%
import pandas as pd
DDD_Address=pd.read_excel(r"C:\Users\HP\Downloads\Insurance_Customers (1).xlsx",sheet_name="DDD_Address")
DDD_Address
# Out:
#        patientid  membershipid  groupid   person_nbr Primary_Phone_NBR  \
# 0         200001   4456.162497      100  2748.280106                 C
# 1         200002   4456.162497      100  3983.633278                 C
# 2         200003   4456.162497      100  5918.043203                 C
# 3         200004   4456.162497      100  5882.418134                 C
# 4         200005   4456.162497      100  3519.095855                 C
# ...          ...           ...      ...          ...               ...
# 84006     284007  61967.640577      108  6406.791285                 C
# 84007     284008  61967.640577      108  5736.801838                 C
# 84008     284009  61967.640577      108  7613.994822                 C
# 84009     284010  61967.640577      108  8530.577571                 C
# 84010     284011  61967.640577      108  2140.830791                 C
#
#       Phone2_NBR Phone3_NBR
# 0              O          C
# 1              O          C
# ...

# %%
DDD_Address.columns
# Out:
# Index(['patientid', 'membershipid', 'groupid', 'person_nbr',
#        'Primary_Phone_NBR', 'Phone2_NBR', 'Phone3_NBR'],
#       dtype='object')

# %%
DDD_Address.head()
# Out:
#    patientid  membershipid  groupid   person_nbr Primary_Phone_NBR Phone2_NBR  \
# 0     200001   4456.162497      100  2748.280106                 C          O
# 1     200002   4456.162497      100  3983.633278                 C          O
# 2     200003   4456.162497      100  5918.043203                 C          O
# 3     200004   4456.162497      100  5882.418134                 C          O
# 4     200005   4456.162497      100  3519.095855                 C          O
#
#   Phone3_NBR
# 0          C
# 1          C
# 2          C
# 3          C
# 4          C

# %%
DDD_Address.tail()
# Out:
#        patientid  membershipid  groupid   person_nbr Primary_Phone_NBR  \
# 84006     284007  61967.640577      108  6406.791285                 C
# 84007     284008  61967.640577      108  5736.801838                 C
# 84008     284009  61967.640577      108  7613.994822                 C
# 84009     284010  61967.640577      108  8530.577571                 C
# 84010     284011  61967.640577      108  2140.830791                 C
#
#       Phone2_NBR Phone3_NBR
# 84006          C          C
# 84007          C          C
# 84008          C          C
# 84009          C          C
# 84010          C          C

# %%
DDD_Address.shape
# Out:
# (84011, 7)

# %%
#leftmerge.

# %%
DDD_l_merge=DDD_Patients.merge(DDD_Address,how="left",on=["patientid","membershipid","groupid","person_nbr"])
DDD_l_merge
# Out:
#        patientid  membershipid  groupid   person_nbr Primary_Phone_NBR  \
# 0         200001   4456.162497      100  2748.280106                 C
# 1         200002   4456.162497      100  3983.633278                 C
# 2         200003   4456.162497      100  5918.043203                 C
# 3         200004   4456.162497      100  5882.418134                 C
# 4         200005   4456.162497      100  3519.095855                 C
# ...          ...           ...      ...          ...               ...
# 84006     284007  61967.640577      108  6406.791285                 C
# 84007     284008  61967.640577      108  5736.801838                 C
# 84008     284009  61967.640577      108  7613.994822                 C
# 84009     284010  61967.640577      108  8530.577571                 C
# 84010     284011  61967.640577      108  2140.830791                 C
#
#       Phone2_NBR Phone3_NBR
# 0              O          C
# 1              O          C
# ...

# %%
DDD_Patients.columns
# Out:
# Index(['patientid', 'membershipid', 'groupid', 'person_nbr'], dtype='object')

# %%
import pandas as pd
DDD_Flag=pd.read_excel(r"C:\Users\HP\Downloads\Insurance_Customers (1).xlsx",sheet_name="DDD_Flag")
DDD_Flag
# Out:
#    groupid        Flag
# 0      100        EarD
# 1      102       EyesD
# 2      103     Nervers
# 3      105       KneeF
# 4      106      SpineF
# 5      107     Obesity
# 6      108  Obesity-II

# %%
DDD_l_DDD_Flag_merge=DDD_l_merge.merge(DDD_Flag,how="left",on="groupid")
DDD_l_DDD_Flag_merge
# Out:
#        patientid  membershipid  groupid   person_nbr Primary_Phone_NBR  \
# 0         200001   4456.162497      100  2748.280106                 C
# 1         200002   4456.162497      100  3983.633278                 C
# 2         200003   4456.162497      100  5918.043203                 C
# 3         200004   4456.162497      100  5882.418134                 C
# 4         200005   4456.162497      100  3519.095855                 C
# ...          ...           ...      ...          ...               ...
# 84006     284007  61967.640577      108  6406.791285                 C
# 84007     284008  61967.640577      108  5736.801838                 C
# 84008     284009  61967.640577      108  7613.994822                 C
# 84009     284010  61967.640577      108  8530.577571                 C
# 84010     284011  61967.640577      108  2140.830791                 C
#
#       Phone2_NBR Phone3_NBR        Flag
# 0              O          C        EarD
# ...

# %%
cell_flag=""
DDD_l_DDD_Flag_merge["cell_flag"]=cell_flag
DDD_l_DDD_Flag_merge
# Out:
#        patientid  membershipid  groupid   person_nbr Primary_Phone_NBR  \
# 0         200001   4456.162497      100  2748.280106                 C
# 1         200002   4456.162497      100  3983.633278                 C
# 2         200003   4456.162497      100  5918.043203                 C
# 3         200004   4456.162497      100  5882.418134                 C
# 4         200005   4456.162497      100  3519.095855                 C
# ...          ...           ...      ...          ...               ...
# 84006     284007  61967.640577      108  6406.791285                 C
# 84007     284008  61967.640577      108  5736.801838                 C
# 84008     284009  61967.640577      108  7613.994822                 C
# 84009     284010  61967.640577      108  8530.577571                 C
# 84010     284011  61967.640577      108  2140.830791                 C
#
#       Phone2_NBR Phone3_NBR        Flag cell_flag
# 0              O          C        EarD
# ...

# %%
DDD_l_DDD_Flag_merge.columns
# Out:
# Index(['patientid', 'membershipid', 'groupid', 'person_nbr',
#        'Primary_Phone_NBR', 'Phone2_NBR', 'Phone3_NBR', 'Flag', 'cell_flag'],
#       dtype='object')

# %%
import numpy as np

# %%
DDD_l_DDD_Flag_merge["cell_flag"]=np.where(DDD_l_DDD_Flag_merge["Primary_Phone_NBR"]=="C","P",DDD_l_DDD_Flag_merge["cell_flag"])
DDD_l_DDD_Flag_merge
# Out:
#        patientid  membershipid  groupid   person_nbr Primary_Phone_NBR  \
# 0         200001   4456.162497      100  2748.280106                 C
# 1         200002   4456.162497      100  3983.633278                 C
# 2         200003   4456.162497      100  5918.043203                 C
# 3         200004   4456.162497      100  5882.418134                 C
# 4         200005   4456.162497      100  3519.095855                 C
# ...          ...           ...      ...          ...               ...
# 84006     284007  61967.640577      108  6406.791285                 C
# 84007     284008  61967.640577      108  5736.801838                 C
# 84008     284009  61967.640577      108  7613.994822                 C
# 84009     284010  61967.640577      108  8530.577571                 C
# 84010     284011  61967.640577      108  2140.830791                 C
#
#       Phone2_NBR Phone3_NBR        Flag cell_flag
# 0              O          C        EarD         P
# ...

# %%
DDD_l_DDD_Flag_merge.cell_flag.unique()
# Out:
# array(['P', ''], dtype=object)

# %%
DDD_l_DDD_Flag_merge["cell_flag"]=np.where(DDD_l_DDD_Flag_merge["Primary_Phone_NBR"]!="C","S",DDD_l_DDD_Flag_merge["cell_flag"])
DDD_l_DDD_Flag_merge
# Out:
#        patientid  membershipid  groupid   person_nbr Primary_Phone_NBR  \
# 0         200001   4456.162497      100  2748.280106                 C
# 1         200002   4456.162497      100  3983.633278                 C
# 2         200003   4456.162497      100  5918.043203                 C
# 3         200004   4456.162497      100  5882.418134                 C
# 4         200005   4456.162497      100  3519.095855                 C
# ...          ...           ...      ...          ...               ...
# 84006     284007  61967.640577      108  6406.791285                 C
# 84007     284008  61967.640577      108  5736.801838                 C
# 84008     284009  61967.640577      108  7613.994822                 C
# 84009     284010  61967.640577      108  8530.577571                 C
# 84010     284011  61967.640577      108  2140.830791                 C
#
#       Phone2_NBR Phone3_NBR        Flag cell_flag
# 0              O          C        EarD         P
# ...

# %%
DDD_l_DDD_Flag_merge.cell_flag.unique()
# Out:
# array(['P', 'S'], dtype=object)

# %%
DDD_l_DDD_Flag_merge.cell_flag.value_counts()
# Out:
# P    81589
# S     2422
# Name: cell_flag, dtype: int64

# %%
lst=["C","O","H"]

# %%
DDD_l_DDD_Flag_merge["cell_flag"]=np.where(~DDD_l_DDD_Flag_merge["Primary_Phone_NBR"].isin(lst),"N",DDD_l_DDD_Flag_merge["cell_flag"])
DDD_l_DDD_Flag_merge
# Out:
#        patientid  membershipid  groupid   person_nbr Primary_Phone_NBR  \
# 0         200001   4456.162497      100  2748.280106                 C
# 1         200002   4456.162497      100  3983.633278                 C
# 2         200003   4456.162497      100  5918.043203                 C
# 3         200004   4456.162497      100  5882.418134                 C
# 4         200005   4456.162497      100  3519.095855                 C
# ...          ...           ...      ...          ...               ...
# 84006     284007  61967.640577      108  6406.791285                 C
# 84007     284008  61967.640577      108  5736.801838                 C
# 84008     284009  61967.640577      108  7613.994822                 C
# 84009     284010  61967.640577      108  8530.577571                 C
# 84010     284011  61967.640577      108  2140.830791                 C
#
#       Phone2_NBR Phone3_NBR        Flag cell_flag
# 0              O          C        EarD         P
# ...

# %%
DDD_l_DDD_Flag_merge.cell_flag.unique()
# Out:
# array(['P', 'S'], dtype=object)

# %%
DDD_l_DDD_Flag_merge.cell_flag.value_counts()
# Out:
# P    81589
# S     2422
# Name: cell_flag, dtype: int64

# %%
DDD_l_DDD_Flag_merge["Flag"]="Total DDD_Patients"
DDD_l_DDD_Flag_merge
# Out:
#        patientid  membershipid  groupid   person_nbr Primary_Phone_NBR  \
# 0         200001   4456.162497      100  2748.280106                 C
# 1         200002   4456.162497      100  3983.633278                 C
# 2         200003   4456.162497      100  5918.043203                 C
# 3         200004   4456.162497      100  5882.418134                 C
# 4         200005   4456.162497      100  3519.095855                 C
# ...          ...           ...      ...          ...               ...
# 84006     284007  61967.640577      108  6406.791285                 C
# 84007     284008  61967.640577      108  5736.801838                 C
# 84008     284009  61967.640577      108  7613.994822                 C
# 84009     284010  61967.640577      108  8530.577571                 C
# 84010     284011  61967.640577      108  2140.830791                 C
#
#       Phone2_NBR Phone3_NBR                Flag cell_flag
# ...

# %%
DDD_l_DDD_Flag_merge_P=DDD_l_DDD_Flag_merge[DDD_l_DDD_Flag_merge.cell_flag=="P"]
DDD_l_DDD_Flag_merge_P["Flag"]="Total DDD_Patients for cell_flag P"
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5064\866615443.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DDD_l_DDD_Flag_merge_P["Flag"]="Total DDD_Patients for cell_flag P"

# %%
DDD_l_DDD_Flag_merge_P
# Out:
#        patientid  membershipid  groupid   person_nbr Primary_Phone_NBR  \
# 0         200001   4456.162497      100  2748.280106                 C
# 1         200002   4456.162497      100  3983.633278                 C
# 2         200003   4456.162497      100  5918.043203                 C
# 3         200004   4456.162497      100  5882.418134                 C
# 4         200005   4456.162497      100  3519.095855                 C
# ...          ...           ...      ...          ...               ...
# 84006     284007  61967.640577      108  6406.791285                 C
# 84007     284008  61967.640577      108  5736.801838                 C
# 84008     284009  61967.640577      108  7613.994822                 C
# 84009     284010  61967.640577      108  8530.577571                 C
# 84010     284011  61967.640577      108  2140.830791                 C
#
#       Phone2_NBR Phone3_NBR                                Flag cell_flag
# ...

# %%
DDD_l_DDD_Flag_merge_S=DDD_l_DDD_Flag_merge[DDD_l_DDD_Flag_merge.cell_flag=="S"]
DDD_l_DDD_Flag_merge_S["Flag"]="Total DDD_Patients for cell_flag S"
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5064\2493695145.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DDD_l_DDD_Flag_merge_S["Flag"]="Total DDD_Patients for cell_flag S"

# %%
DDD_l_DDD_Flag_merge_S
# Out:
#       patientid  membershipid  groupid   person_nbr Primary_Phone_NBR  \
# 614      200615   4456.162497      100  6677.313951                 O
# 615      200616   4456.162497      100  2462.055205                 O
# 616      200617   4456.162497      100  3429.345531                 O
# 617      200618   4456.162497      100  9685.907698                 O
# 618      200619   4456.162497      100  4297.300386                 O
# ...         ...           ...      ...          ...               ...
# 3031     203032  11928.016776      100  2816.560876                 H
# 3032     203033  11928.016776      100  1722.102601                 H
# 3033     203034  11928.016776      100  4944.903288                 H
# 3034     203035  11928.016776      100  8644.975125                 H
# 3035     203036  11928.016776      100  1595.251060                 H
#
#      Phone2_NBR Phone3_NBR                                Flag cell_flag
# ...

# %%
DDD_l_DDD_Flag_merge_N=DDD_l_DDD_Flag_merge[DDD_l_DDD_Flag_merge.cell_flag=="N"]
DDD_l_DDD_Flag_merge_N["Flag"]="Total DDD_Patients for cell_flag N"

# %%
DDD_l_DDD_Flag_merge_N
# Out:
# Empty DataFrame
# Columns: [patientid, membershipid, groupid, person_nbr, Primary_Phone_NBR, Phone2_NBR, Phone3_NBR, Flag, cell_flag]
# Index: []

# %%
#checks:

# %%
DDD_l_DDD_Flag_merge_P.head()
# Out:
#    patientid  membershipid  groupid   person_nbr Primary_Phone_NBR Phone2_NBR  \
# 0     200001   4456.162497      100  2748.280106                 C          O
# 1     200002   4456.162497      100  3983.633278                 C          O
# 2     200003   4456.162497      100  5918.043203                 C          O
# 3     200004   4456.162497      100  5882.418134                 C          O
# 4     200005   4456.162497      100  3519.095855                 C          O
#
#   Phone3_NBR                                Flag cell_flag
# 0          C  Total DDD_Patients for cell_flag P         P
# 1          C  Total DDD_Patients for cell_flag P         P
# 2          C  Total DDD_Patients for cell_flag P         P
# 3          C  Total DDD_Patients for cell_flag P         P
# 4          C  Total DDD_Patients for cell_flag P         P

# %%
DDD_l_DDD_Flag_merge_P.tail()
# Out:
#        patientid  membershipid  groupid   person_nbr Primary_Phone_NBR  \
# 84006     284007  61967.640577      108  6406.791285                 C
# 84007     284008  61967.640577      108  5736.801838                 C
# 84008     284009  61967.640577      108  7613.994822                 C
# 84009     284010  61967.640577      108  8530.577571                 C
# 84010     284011  61967.640577      108  2140.830791                 C
#
#       Phone2_NBR Phone3_NBR                                Flag cell_flag
# 84006          C          C  Total DDD_Patients for cell_flag P         P
# 84007          C          C  Total DDD_Patients for cell_flag P         P
# 84008          C          C  Total DDD_Patients for cell_flag P         P
# 84009          C          C  Total DDD_Patients for cell_flag P         P
# 84010          C          C  Total DDD_Patients for cell_flag P         P

# %%
DDD_l_DDD_Flag_merge_S.head()
# Out:
#      patientid  membershipid  groupid   person_nbr Primary_Phone_NBR  \
# 614     200615   4456.162497      100  6677.313951                 O
# 615     200616   4456.162497      100  2462.055205                 O
# 616     200617   4456.162497      100  3429.345531                 O
# 617     200618   4456.162497      100  9685.907698                 O
# 618     200619   4456.162497      100  4297.300386                 O
#
#     Phone2_NBR Phone3_NBR                                Flag cell_flag
# 614          C          O  Total DDD_Patients for cell_flag S         S
# 615          C          O  Total DDD_Patients for cell_flag S         S
# 616          C          O  Total DDD_Patients for cell_flag S         S
# 617          C          O  Total DDD_Patients for cell_flag S         S
# 618          C          O  Total DDD_Patients for cell_flag S         S

# %%
DDD_l_DDD_Flag_merge_S.tail()
# Out:
#       patientid  membershipid  groupid   person_nbr Primary_Phone_NBR  \
# 3031     203032  11928.016776      100  2816.560876                 H
# 3032     203033  11928.016776      100  1722.102601                 H
# 3033     203034  11928.016776      100  4944.903288                 H
# 3034     203035  11928.016776      100  8644.975125                 H
# 3035     203036  11928.016776      100  1595.251060                 H
#
#      Phone2_NBR Phone3_NBR                                Flag cell_flag
# 3031          C          O  Total DDD_Patients for cell_flag S         S
# 3032          C          O  Total DDD_Patients for cell_flag S         S
# 3033          C          O  Total DDD_Patients for cell_flag S         S
# 3034          C          O  Total DDD_Patients for cell_flag S         S
# 3035          C          O  Total DDD_Patients for cell_flag S         S

# %%
DDD_l_DDD_Flag_merge_N.head()
# Out:
# Empty DataFrame
# Columns: [patientid, membershipid, groupid, person_nbr, Primary_Phone_NBR, Phone2_NBR, Phone3_NBR, Flag, cell_flag]
# Index: []

# %%
DDD_l_DDD_Flag_merge_N.tail()
# Out:
# Empty DataFrame
# Columns: [patientid, membershipid, groupid, person_nbr, Primary_Phone_NBR, Phone2_NBR, Phone3_NBR, Flag, cell_flag]
# Index: []

# %%
####summarisation

# %%
DDD_l_DDD_Flag_merge_sm=DDD_l_DDD_Flag_merge.groupby(["Flag"])["patientid"].count()
DDD_l_DDD_Flag_merge_sm_ndf=pd.DataFrame(DDD_l_DDD_Flag_merge_sm)
DDD_l_DDD_Flag_merge_sm_ndf.reset_index(inplace=True)

# %%
DDD_l_DDD_Flag_merge_sm_ndf
# Out:
#                  Flag  patientid
# 0  Total DDD_Patients      84011

# %%
DDD_l_DDD_Flag_merge_P_sm=DDD_l_DDD_Flag_merge_P.groupby(["Flag"])["patientid"].count()
DDD_l_DDD_Flag_merge_P_sm_ndf=pd.DataFrame(DDD_l_DDD_Flag_merge_P_sm)
DDD_l_DDD_Flag_merge_P_sm_ndf.reset_index(inplace=True)

# %%
DDD_l_DDD_Flag_merge_P_sm_ndf
# Out:
#                                  Flag  patientid
# 0  Total DDD_Patients for cell_flag P      81589

# %%
DDD_l_DDD_Flag_merge_S_sm=DDD_l_DDD_Flag_merge_S.groupby(["Flag"])["patientid"].count()
DDD_l_DDD_Flag_merge_S_sm_ndf=pd.DataFrame(DDD_l_DDD_Flag_merge_S_sm)
DDD_l_DDD_Flag_merge_S_sm_ndf.reset_index(inplace=True)

# %%
DDD_l_DDD_Flag_merge_S_sm_ndf
# Out:
#                                  Flag  patientid
# 0  Total DDD_Patients for cell_flag S       2422

# %%
DDD_l_DDD_Flag_merge_N_sm=DDD_l_DDD_Flag_merge_N.groupby(["Flag"])["patientid"].count()
DDD_l_DDD_Flag_merge_N_sm_ndf=pd.DataFrame(DDD_l_DDD_Flag_merge_N_sm)
DDD_l_DDD_Flag_merge_N_sm_ndf.reset_index(inplace=True)

# %%
DDD_l_DDD_Flag_merge_N_sm_ndf
# Out:
# Empty DataFrame
# Columns: [Flag, patientid]
# Index: []

# %%
## append

# %%
final_df3=pd.concat([DDD_l_DDD_Flag_merge_sm_ndf,DDD_l_DDD_Flag_merge_P_sm_ndf,DDD_l_DDD_Flag_merge_S_sm_ndf,DDD_l_DDD_Flag_merge_N_sm_ndf],ignore_index=True,axis=0)
final_df3
# Out:
#                                  Flag  patientid
# 0                  Total DDD_Patients      84011
# 1  Total DDD_Patients for cell_flag P      81589
# 2  Total DDD_Patients for cell_flag S       2422

# %%
final_df3.columns=["Flag","Count"]
final_df3
# Out:
#                                  Flag  Count
# 0                  Total DDD_Patients  84011
# 1  Total DDD_Patients for cell_flag P  81589
# 2  Total DDD_Patients for cell_flag S   2422

# %%
import pandas as pd
df3=pd.DataFrame()
df3
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import time
now=time.localtime()
T=time.strftime("%H : %M : %S,",now)
print(T)
# Out:
# 16 : 40 : 19,

# %%
from datetime import date
today=date.today()
print("today=",today)
# Out:
# today= 2023-08-29

# %%
today
# Out:
# datetime.date(2023, 8, 29)

# %%
final_df3["Time"]=T
final_df3["Date"]=today
final_df3
# Out:
#                                  Flag  Count           Time        Date
# 0                  Total DDD_Patients  84011  16 : 40 : 19,  2023-08-29
# 1  Total DDD_Patients for cell_flag P  81589  16 : 40 : 19,  2023-08-29
# 2  Total DDD_Patients for cell_flag S   2422  16 : 40 : 19,  2023-08-29

# %%
import pandas as pd
DDD_Patients=pd.read_excel(r"C:\Users\HP\Downloads\Insurance_Customers (1).xlsx",sheet_name="DDD_Patients")
DDD_Patients
# Out:
#        patientid  membershipid  groupid   person_nbr
# 0         200001   4456.162497      100  2748.280106
# 1         200002   4456.162497      100  3983.633278
# 2         200003   4456.162497      100  5918.043203
# 3         200004   4456.162497      100  5882.418134
# 4         200005   4456.162497      100  3519.095855
# ...          ...           ...      ...          ...
# 84006     284007  61967.640577      108  6406.791285
# 84007     284008  61967.640577      108  5736.801838
# 84008     284009  61967.640577      108  7613.994822
# 84009     284010  61967.640577      108  8530.577571
# 84010     284011  61967.640577      108  2140.830791
#
# [84011 rows x 4 columns]

# %%
DDD_Patients.head()
# Out:
#    patientid  membershipid  groupid   person_nbr
# 0     200001   4456.162497      100  2748.280106
# 1     200002   4456.162497      100  3983.633278
# 2     200003   4456.162497      100  5918.043203
# 3     200004   4456.162497      100  5882.418134
# 4     200005   4456.162497      100  3519.095855

# %%
DDD_Patients.tail()
# Out:
#        patientid  membershipid  groupid   person_nbr
# 84006     284007  61967.640577      108  6406.791285
# 84007     284008  61967.640577      108  5736.801838
# 84008     284009  61967.640577      108  7613.994822
# 84009     284010  61967.640577      108  8530.577571
# 84010     284011  61967.640577      108  2140.830791

# %%
import pandas as pd
DDD_Address=pd.read_excel(r"C:\Users\HP\Downloads\Insurance_Customers (1).xlsx",sheet_name="DDD_Address")
DDD_Address
# Out:
#        patientid  membershipid  groupid   person_nbr Primary_Phone_NBR  \
# 0         200001   4456.162497      100  2748.280106                 C
# 1         200002   4456.162497      100  3983.633278                 C
# 2         200003   4456.162497      100  5918.043203                 C
# 3         200004   4456.162497      100  5882.418134                 C
# 4         200005   4456.162497      100  3519.095855                 C
# ...          ...           ...      ...          ...               ...
# 84006     284007  61967.640577      108  6406.791285                 C
# 84007     284008  61967.640577      108  5736.801838                 C
# 84008     284009  61967.640577      108  7613.994822                 C
# 84009     284010  61967.640577      108  8530.577571                 C
# 84010     284011  61967.640577      108  2140.830791                 C
#
#       Phone2_NBR Phone3_NBR
# 0              O          C
# 1              O          C
# ...

# %%
DDD_Address.head()
# Out:
#    patientid  membershipid  groupid   person_nbr Primary_Phone_NBR Phone2_NBR  \
# 0     200001   4456.162497      100  2748.280106                 C          O
# 1     200002   4456.162497      100  3983.633278                 C          O
# 2     200003   4456.162497      100  5918.043203                 C          O
# 3     200004   4456.162497      100  5882.418134                 C          O
# 4     200005   4456.162497      100  3519.095855                 C          O
#
#   Phone3_NBR
# 0          C
# 1          C
# 2          C
# 3          C
# 4          C

# %%
DDD_Address.tail()
# Out:
#        patientid  membershipid  groupid   person_nbr Primary_Phone_NBR  \
# 84006     284007  61967.640577      108  6406.791285                 C
# 84007     284008  61967.640577      108  5736.801838                 C
# 84008     284009  61967.640577      108  7613.994822                 C
# 84009     284010  61967.640577      108  8530.577571                 C
# 84010     284011  61967.640577      108  2140.830791                 C
#
#       Phone2_NBR Phone3_NBR
# 84006          C          C
# 84007          C          C
# 84008          C          C
# 84009          C          C
# 84010          C          C

# %%
DDD_Patients.columns
# Out:
# Index(['patientid', 'membershipid', 'groupid', 'person_nbr'], dtype='object')

# %%
###left merge

# %%
DDD_l_merge=DDD_Patients.merge(DDD_Address,how="left",on=["patientid","membershipid","groupid"])
DDD_l_merge
# Out:
#        patientid  membershipid  groupid  person_nbr_x  person_nbr_y  \
# 0         200001   4456.162497      100   2748.280106   2748.280106
# 1         200002   4456.162497      100   3983.633278   3983.633278
# 2         200003   4456.162497      100   5918.043203   5918.043203
# 3         200004   4456.162497      100   5882.418134   5882.418134
# 4         200005   4456.162497      100   3519.095855   3519.095855
# ...          ...           ...      ...           ...           ...
# 84006     284007  61967.640577      108   6406.791285   6406.791285
# 84007     284008  61967.640577      108   5736.801838   5736.801838
# 84008     284009  61967.640577      108   7613.994822   7613.994822
# 84009     284010  61967.640577      108   8530.577571   8530.577571
# 84010     284011  61967.640577      108   2140.830791   2140.830791
#
#       Primary_Phone_NBR Phone2_NBR Phone3_NBR
# 0                     C          O          C
# 1                     C          O          C
# ...

# %%
DDD_l_merge.columns
# Out:
# Index(['patientid', 'membershipid', 'groupid', 'person_nbr_x', 'person_nbr_y',
#        'Primary_Phone_NBR', 'Phone2_NBR', 'Phone3_NBR'],
#       dtype='object')

# %%
DDD_l_merge_filter=DDD_l_merge[['patientid','membershipid','groupid','person_nbr_x',
       'Primary_Phone_NBR','Phone2_NBR','Phone3_NBR']]

# %%
DDD_l_merge_filter
# Out:
#        patientid  membershipid  groupid  person_nbr_x Primary_Phone_NBR  \
# 0         200001   4456.162497      100   2748.280106                 C
# 1         200002   4456.162497      100   3983.633278                 C
# 2         200003   4456.162497      100   5918.043203                 C
# 3         200004   4456.162497      100   5882.418134                 C
# 4         200005   4456.162497      100   3519.095855                 C
# ...          ...           ...      ...           ...               ...
# 84006     284007  61967.640577      108   6406.791285                 C
# 84007     284008  61967.640577      108   5736.801838                 C
# 84008     284009  61967.640577      108   7613.994822                 C
# 84009     284010  61967.640577      108   8530.577571                 C
# 84010     284011  61967.640577      108   2140.830791                 C
#
#       Phone2_NBR Phone3_NBR
# 0              O          C
# 1              O          C
# ...

# %%
import pandas as pd
DDD_Flag=pd.read_excel(r"C:\Users\HP\Downloads\Insurance_Customers (1).xlsx",sheet_name="DDD_Flag")
DDD_Flag
# Out:
#    groupid        Flag
# 0      100        EarD
# 1      102       EyesD
# 2      103     Nervers
# 3      105       KneeF
# 4      106      SpineF
# 5      107     Obesity
# 6      108  Obesity-II

# %%
DDD_l_merge_filter_Flag_m=DDD_l_merge_filter.merge(DDD_Flag,how="left",on="groupid")
DDD_l_merge_filter_Flag_m
# Out:
#        patientid  membershipid  groupid  person_nbr_x Primary_Phone_NBR  \
# 0         200001   4456.162497      100   2748.280106                 C
# 1         200002   4456.162497      100   3983.633278                 C
# 2         200003   4456.162497      100   5918.043203                 C
# 3         200004   4456.162497      100   5882.418134                 C
# 4         200005   4456.162497      100   3519.095855                 C
# ...          ...           ...      ...           ...               ...
# 84006     284007  61967.640577      108   6406.791285                 C
# 84007     284008  61967.640577      108   5736.801838                 C
# 84008     284009  61967.640577      108   7613.994822                 C
# 84009     284010  61967.640577      108   8530.577571                 C
# 84010     284011  61967.640577      108   2140.830791                 C
#
#       Phone2_NBR Phone3_NBR        Flag
# 0              O          C        EarD
# ...

# %%
cell_flag=" "
DDD_l_merge_filter_Flag_m["cell_flag"]=cell_flag
DDD_l_merge_filter_Flag_m
# Out:
#        patientid  membershipid  groupid  person_nbr_x Primary_Phone_NBR  \
# 0         200001   4456.162497      100   2748.280106                 C
# 1         200002   4456.162497      100   3983.633278                 C
# 2         200003   4456.162497      100   5918.043203                 C
# 3         200004   4456.162497      100   5882.418134                 C
# 4         200005   4456.162497      100   3519.095855                 C
# ...          ...           ...      ...           ...               ...
# 84006     284007  61967.640577      108   6406.791285                 C
# 84007     284008  61967.640577      108   5736.801838                 C
# 84008     284009  61967.640577      108   7613.994822                 C
# 84009     284010  61967.640577      108   8530.577571                 C
# 84010     284011  61967.640577      108   2140.830791                 C
#
#       Phone2_NBR Phone3_NBR        Flag cell_flag
# 0              O          C        EarD
# ...

# %%
DDD_l_merge_filter_Flag_m.columns
# Out:
# Index(['patientid', 'membershipid', 'groupid', 'person_nbr_x',
#        'Primary_Phone_NBR', 'Phone2_NBR', 'Phone3_NBR', 'Flag', 'cell_flag'],
#       dtype='object')

# %%
import numpy as np

# %%
DDD_l_merge_filter_Flag_m["cell_flag"]=np.where(DDD_l_merge_filter_Flag_m["Primary_Phone_NBR"]=="C","P",DDD_l_merge_filter_Flag_m["cell_flag"])
DDD_l_merge_filter_Flag_m
# Out:
#        patientid  membershipid  groupid  person_nbr_x Primary_Phone_NBR  \
# 0         200001   4456.162497      100   2748.280106                 C
# 1         200002   4456.162497      100   3983.633278                 C
# 2         200003   4456.162497      100   5918.043203                 C
# 3         200004   4456.162497      100   5882.418134                 C
# 4         200005   4456.162497      100   3519.095855                 C
# ...          ...           ...      ...           ...               ...
# 84006     284007  61967.640577      108   6406.791285                 C
# 84007     284008  61967.640577      108   5736.801838                 C
# 84008     284009  61967.640577      108   7613.994822                 C
# 84009     284010  61967.640577      108   8530.577571                 C
# 84010     284011  61967.640577      108   2140.830791                 C
#
#       Phone2_NBR Phone3_NBR        Flag cell_flag
# 0              O          C        EarD         P
# ...

# %%
DDD_l_merge_filter_Flag_m.cell_flag.unique()
# Out:
# array(['P', ' '], dtype=object)

# %%
DDD_l_merge_filter_Flag_m["cell_flag"]=np.where(DDD_l_merge_filter_Flag_m["Primary_Phone_NBR"]!="C","S",DDD_l_merge_filter_Flag_m["cell_flag"])
DDD_l_merge_filter_Flag_m
# Out:
#        patientid  membershipid  groupid  person_nbr_x Primary_Phone_NBR  \
# 0         200001   4456.162497      100   2748.280106                 C
# 1         200002   4456.162497      100   3983.633278                 C
# 2         200003   4456.162497      100   5918.043203                 C
# 3         200004   4456.162497      100   5882.418134                 C
# 4         200005   4456.162497      100   3519.095855                 C
# ...          ...           ...      ...           ...               ...
# 84006     284007  61967.640577      108   6406.791285                 C
# 84007     284008  61967.640577      108   5736.801838                 C
# 84008     284009  61967.640577      108   7613.994822                 C
# 84009     284010  61967.640577      108   8530.577571                 C
# 84010     284011  61967.640577      108   2140.830791                 C
#
#       Phone2_NBR Phone3_NBR        Flag cell_flag
# 0              O          C        EarD         P
# ...

# %%
DDD_l_merge_filter_Flag_m.cell_flag.unique()
# Out:
# array(['P', 'S'], dtype=object)

# %%
lst=["C","O","H"]

# %%
DDD_l_merge_filter_Flag_m["cell_flag"]=np.where(~DDD_l_merge_filter_Flag_m["Primary_Phone_NBR"].isin(lst),"N",DDD_l_merge_filter_Flag_m["cell_flag"])
DDD_l_merge_filter_Flag_m
# Out:
#        patientid  membershipid  groupid  person_nbr_x Primary_Phone_NBR  \
# 0         200001   4456.162497      100   2748.280106                 C
# 1         200002   4456.162497      100   3983.633278                 C
# 2         200003   4456.162497      100   5918.043203                 C
# 3         200004   4456.162497      100   5882.418134                 C
# 4         200005   4456.162497      100   3519.095855                 C
# ...          ...           ...      ...           ...               ...
# 84006     284007  61967.640577      108   6406.791285                 C
# 84007     284008  61967.640577      108   5736.801838                 C
# 84008     284009  61967.640577      108   7613.994822                 C
# 84009     284010  61967.640577      108   8530.577571                 C
# 84010     284011  61967.640577      108   2140.830791                 C
#
#       Phone2_NBR Phone3_NBR        Flag cell_flag
# 0              O          C        EarD         P
# ...

# %%
DDD_l_merge_filter_Flag_m.cell_flag.unique()
# Out:
# array(['P', 'S'], dtype=object)

# %%
DDD_l_merge_filter_Flag_m.cell_flag.value_counts()
# Out:
# P    81589
# S     2422
# Name: cell_flag, dtype: int64

# %%
DDD_l_merge_filter_Flag_m["Flag"]="Total DDD_Patients"
DDD_l_merge_filter_Flag_m
# Out:
#        patientid  membershipid  groupid  person_nbr_x Primary_Phone_NBR  \
# 0         200001   4456.162497      100   2748.280106                 C
# 1         200002   4456.162497      100   3983.633278                 C
# 2         200003   4456.162497      100   5918.043203                 C
# 3         200004   4456.162497      100   5882.418134                 C
# 4         200005   4456.162497      100   3519.095855                 C
# ...          ...           ...      ...           ...               ...
# 84006     284007  61967.640577      108   6406.791285                 C
# 84007     284008  61967.640577      108   5736.801838                 C
# 84008     284009  61967.640577      108   7613.994822                 C
# 84009     284010  61967.640577      108   8530.577571                 C
# 84010     284011  61967.640577      108   2140.830791                 C
#
#       Phone2_NBR Phone3_NBR                Flag cell_flag
# ...

# %%
DDD_l_merge_filter_Flag_m_P=DDD_l_merge_filter_Flag_m[DDD_l_merge_filter_Flag_m.cell_flag=="P"]
DDD_l_merge_filter_Flag_m_P["Flag"]="Total DDD_Patients for cell_flag P"
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5064\872464359.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DDD_l_merge_filter_Flag_m_P["Flag"]="Total DDD_Patients for cell_flag P"

# %%
DDD_l_merge_filter_Flag_m_P
# Out:
#        patientid  membershipid  groupid  person_nbr_x Primary_Phone_NBR  \
# 0         200001   4456.162497      100   2748.280106                 C
# 1         200002   4456.162497      100   3983.633278                 C
# 2         200003   4456.162497      100   5918.043203                 C
# 3         200004   4456.162497      100   5882.418134                 C
# 4         200005   4456.162497      100   3519.095855                 C
# ...          ...           ...      ...           ...               ...
# 84006     284007  61967.640577      108   6406.791285                 C
# 84007     284008  61967.640577      108   5736.801838                 C
# 84008     284009  61967.640577      108   7613.994822                 C
# 84009     284010  61967.640577      108   8530.577571                 C
# 84010     284011  61967.640577      108   2140.830791                 C
#
#       Phone2_NBR Phone3_NBR                                Flag cell_flag
# ...

# %%
DDD_l_merge_filter_Flag_m_P.head()
# Out:
#    patientid  membershipid  groupid  person_nbr_x Primary_Phone_NBR  \
# 0     200001   4456.162497      100   2748.280106                 C
# 1     200002   4456.162497      100   3983.633278                 C
# 2     200003   4456.162497      100   5918.043203                 C
# 3     200004   4456.162497      100   5882.418134                 C
# 4     200005   4456.162497      100   3519.095855                 C
#
#   Phone2_NBR Phone3_NBR                                Flag cell_flag
# 0          O          C  Total DDD_Patients for cell_flag P         P
# 1          O          C  Total DDD_Patients for cell_flag P         P
# 2          O          C  Total DDD_Patients for cell_flag P         P
# 3          O          C  Total DDD_Patients for cell_flag P         P
# 4          O          C  Total DDD_Patients for cell_flag P         P

# %%
DDD_l_merge_filter_Flag_m_P.tail()
# Out:
#        patientid  membershipid  groupid  person_nbr_x Primary_Phone_NBR  \
# 84006     284007  61967.640577      108   6406.791285                 C
# 84007     284008  61967.640577      108   5736.801838                 C
# 84008     284009  61967.640577      108   7613.994822                 C
# 84009     284010  61967.640577      108   8530.577571                 C
# 84010     284011  61967.640577      108   2140.830791                 C
#
#       Phone2_NBR Phone3_NBR                                Flag cell_flag
# 84006          C          C  Total DDD_Patients for cell_flag P         P
# 84007          C          C  Total DDD_Patients for cell_flag P         P
# 84008          C          C  Total DDD_Patients for cell_flag P         P
# 84009          C          C  Total DDD_Patients for cell_flag P         P
# 84010          C          C  Total DDD_Patients for cell_flag P         P

# %%
DDD_l_merge_filter_Flag_m_S=DDD_l_merge_filter_Flag_m[DDD_l_merge_filter_Flag_m.cell_flag=="S"]
DDD_l_merge_filter_Flag_m_S["Flag"]="Total DDD_Patients for cell_flag S"
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5064\1424763009.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DDD_l_merge_filter_Flag_m_S["Flag"]="Total DDD_Patients for cell_flag S"

# %%
DDD_l_merge_filter_Flag_m_S
# Out:
#       patientid  membershipid  groupid  person_nbr_x Primary_Phone_NBR  \
# 614      200615   4456.162497      100   6677.313951                 O
# 615      200616   4456.162497      100   2462.055205                 O
# 616      200617   4456.162497      100   3429.345531                 O
# 617      200618   4456.162497      100   9685.907698                 O
# 618      200619   4456.162497      100   4297.300386                 O
# ...         ...           ...      ...           ...               ...
# 3031     203032  11928.016776      100   2816.560876                 H
# 3032     203033  11928.016776      100   1722.102601                 H
# 3033     203034  11928.016776      100   4944.903288                 H
# 3034     203035  11928.016776      100   8644.975125                 H
# 3035     203036  11928.016776      100   1595.251060                 H
#
#      Phone2_NBR Phone3_NBR                                Flag cell_flag
# ...

# %%
DDD_l_merge_filter_Flag_m_S.head()
# Out:
#      patientid  membershipid  groupid  person_nbr_x Primary_Phone_NBR  \
# 614     200615   4456.162497      100   6677.313951                 O
# 615     200616   4456.162497      100   2462.055205                 O
# 616     200617   4456.162497      100   3429.345531                 O
# 617     200618   4456.162497      100   9685.907698                 O
# 618     200619   4456.162497      100   4297.300386                 O
#
#     Phone2_NBR Phone3_NBR                                Flag cell_flag
# 614          C          O  Total DDD_Patients for cell_flag S         S
# 615          C          O  Total DDD_Patients for cell_flag S         S
# 616          C          O  Total DDD_Patients for cell_flag S         S
# 617          C          O  Total DDD_Patients for cell_flag S         S
# 618          C          O  Total DDD_Patients for cell_flag S         S

# %%
DDD_l_merge_filter_Flag_m_S.tail()
# Out:
#       patientid  membershipid  groupid  person_nbr_x Primary_Phone_NBR  \
# 3031     203032  11928.016776      100   2816.560876                 H
# 3032     203033  11928.016776      100   1722.102601                 H
# 3033     203034  11928.016776      100   4944.903288                 H
# 3034     203035  11928.016776      100   8644.975125                 H
# 3035     203036  11928.016776      100   1595.251060                 H
#
#      Phone2_NBR Phone3_NBR                                Flag cell_flag
# 3031          C          O  Total DDD_Patients for cell_flag S         S
# 3032          C          O  Total DDD_Patients for cell_flag S         S
# 3033          C          O  Total DDD_Patients for cell_flag S         S
# 3034          C          O  Total DDD_Patients for cell_flag S         S
# 3035          C          O  Total DDD_Patients for cell_flag S         S

# %%
DDD_l_merge_filter_Flag_m_N=DDD_l_merge_filter_Flag_m[DDD_l_merge_filter_Flag_m.cell_flag=="N"]
DDD_l_merge_filter_Flag_m_N["Flag"]="Total DDD_Patients for cell_flag N"

# %%
DDD_l_merge_filter_Flag_m_N
# Out:
# Empty DataFrame
# Columns: [patientid, membershipid, groupid, person_nbr_x, Primary_Phone_NBR, Phone2_NBR, Phone3_NBR, Flag, cell_flag]
# Index: []

# %%
####summarisation##

# %%
DDD_l_merge_filter_Flag_m_sm=DDD_l_merge_filter_Flag_m.groupby(["Flag"])["patientid"].count()
DDD_l_merge_filter_Flag_m_sm_ndf=pd.DataFrame(DDD_l_merge_filter_Flag_m_sm)
DDD_l_merge_filter_Flag_m_sm_ndf.reset_index(inplace=True)

# %%
DDD_l_merge_filter_Flag_m_sm_ndf
# Out:
#                  Flag  patientid
# 0  Total DDD_Patients      84011

# %%
DDD_l_merge_filter_Flag_m_P_sm=DDD_l_merge_filter_Flag_m_P.groupby(["Flag"])["patientid"].count()
DDD_l_merge_filter_Flag_m_P_sm_ndf=pd.DataFrame(DDD_l_merge_filter_Flag_m_P_sm)
DDD_l_merge_filter_Flag_m_P_sm_ndf.reset_index(inplace=True)

# %%
DDD_l_merge_filter_Flag_m_P_sm_ndf
# Out:
#                                  Flag  patientid
# 0  Total DDD_Patients for cell_flag P      81589

# %%
DDD_l_merge_filter_Flag_m_S_sm=DDD_l_merge_filter_Flag_m_S.groupby(["Flag"])["patientid"].count()
DDD_l_merge_filter_Flag_m_S_sm_ndf=pd.DataFrame(DDD_l_merge_filter_Flag_m_S_sm)
DDD_l_merge_filter_Flag_m_S_sm_ndf.reset_index(inplace=True)

# %%
DDD_l_merge_filter_Flag_m_S_sm_ndf
# Out:
#                                  Flag  patientid
# 0  Total DDD_Patients for cell_flag S       2422

# %%
DDD_l_merge_filter_Flag_m_N_sm=DDD_l_merge_filter_Flag_m_N.groupby(["Flag"])["patientid"].count()
DDD_l_merge_filter_Flag_m_N_sm_ndf=pd.DataFrame(DDD_l_merge_filter_Flag_m_N_sm)
DDD_l_merge_filter_Flag_m_N_sm_ndf.reset_index(inplace=True)

# %%
DDD_l_merge_filter_Flag_m_N_sm_ndf
# Out:
# Empty DataFrame
# Columns: [Flag, patientid]
# Index: []

# %%
###append

# %%
final_df4=pd.concat([DDD_l_merge_filter_Flag_m_sm_ndf,DDD_l_merge_filter_Flag_m_P_sm_ndf,DDD_l_merge_filter_Flag_m_S_sm_ndf,DDD_l_merge_filter_Flag_m_N_sm_ndf],ignore_index="True",axis=0)
final_df4
# Out:
#                                  Flag  patientid
# 0                  Total DDD_Patients      84011
# 1  Total DDD_Patients for cell_flag P      81589
# 2  Total DDD_Patients for cell_flag S       2422

# %%
final_df4.columns=["Flag","Count"]
final_df4
# Out:
#                                  Flag  Count
# 0                  Total DDD_Patients  84011
# 1  Total DDD_Patients for cell_flag P  81589
# 2  Total DDD_Patients for cell_flag S   2422

# %%
import pandas as pd
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import time
now=time.localtime()
T=time.strftime("%H : %M : %S,",now)
print(T)
# Out:
# 16 : 40 : 34,

# %%
from datetime import date
today=date.today()
print("today=",today)
# Out:
# today= 2023-08-29

# %%
today
# Out:
# datetime.date(2023, 8, 29)

# %%
final_df4["Time"]=T
final_df4["Date"]=today
final_df4
# Out:
#                                  Flag  Count           Time        Date
# 0                  Total DDD_Patients  84011  16 : 40 : 34,  2023-08-29
# 1  Total DDD_Patients for cell_flag P  81589  16 : 40 : 34,  2023-08-29
# 2  Total DDD_Patients for cell_flag S   2422  16 : 40 : 34,  2023-08-29

# %%
final_df=pd.concat([final_df1,final_df2,final_df3,final_df4],axis=0,ignore_index="True")

# %%
final_df
# Out:
#                                   Date           Time  \
# 0                   total BBB_Patients          10119
# 1   Total BBB patients for cell_flag P           3747
# 2   Total BBB patients for cell_flag S           6202
# 3   Total BBB patients for cell_flag N            170
# 4                           2023-08-29  16 : 40 : 04,
# 5                           2023-08-29  16 : 40 : 04,
# 6                           2023-08-29  16 : 40 : 04,
# 7                           2023-08-29  16 : 40 : 04,
# 8                           2023-08-29  16 : 40 : 19,
# 9                           2023-08-29  16 : 40 : 19,
# 10                          2023-08-29  16 : 40 : 19,
# 11                          2023-08-29  16 : 40 : 34,
# 12                          2023-08-29  16 : 40 : 34,
# 13                          2023-08-29  16 : 40 : 34,
#
#                                   Flag       Count
# 0                        16 : 40 : 02,  2023-08-29
# ...
